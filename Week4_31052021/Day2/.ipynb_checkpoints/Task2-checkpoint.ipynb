# %% [markdown]
# # Column Manipulation of Pandas DataFrames

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas, pathlib, and numpy libraries
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
data = r'C:\Users\TribThapa\Desktop\Thapa\ResearchFellow\Courses\FinTech_Bootcamp_MonashUni2021\monu-mel-virt-fin-pt-05-2021-u-c\Activities\Week 4\2\02-columns-01\Resources\people.csv'

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame and Display a Few Rows

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
data_df = pd.read_csv(data) 
data_df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 4. View Column Names

# %%
# Use the `columns` attribute to output the column names
data_df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'uni_grad',
#        'job_title', 'Income'],
#       dtype='object')

# %% [markdown]
# ### 5. View Column Data Types

# %%
# Use the `dtypes` attribute to output the column names and data types
data_df.dtypes
# Out:
# id            float64
# first_name     object
# last_name      object
# email          object
# gender         object
# uni_grad       object
# job_title      object
# Income        float64
# dtype: object

# %% [markdown]
# ### 6. Rename Columns Using List

# %%
# Set the `columns` attribute to a new list of column names
col_names = ['ID', 'First Name', 'Last Name', 'Email', 'Gender', 'University', 'Job', 'Income']

data_df.columns = [col_names]
data_df
# Out:
#          ID First Name    Last Name                            Email  Gender  \
# 0       1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1       2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2       3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3       4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4       5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
# ..      ...        ...          ...                              ...     ...
# 995   996.0       Meta     Crumpton               mcrumptonrn@qq.com  Female
# 996   997.0      Gunar      Gilford             ggilfordro@yandex.ru    Male
# 997   998.0   Lucretia      Gurling                 lgurlingrp@de.vu  Female
# 998   999.0     Andrew         Yang             ayang@codedrills.com    Male
# 999  1000.0     Andrew         Yang             ayang@codedrills.com    Male
#
#                                             University                    Job  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# 4                               Boise State University        Project Manager
# ..                                                 ...                    ...
# 995               ECAM - Institut Supérieur Industriel       Registered Nurse
# 996                                  Smolny University      Marketing Manager
# 997                          Institut Teknologi Telkom  Software Engineer III
# 998              Rutgers University School of Business    Curriculum Engineer
# 999              Rutgers University School of Business    Curriculum Engineer
#
#       Income
# 0    58135.0
# 1    96053.0
# 2    59196.0
# 3    88493.0
# 4    89073.0
# ..       ...
# 995  57060.0
# 996  76109.0
# 997  92115.0
# 998  60000.0
# 999  60000.0
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### 7. Rename Columns Using Dictionary

# %%
# Use the `rename` function and set the `columns` parameter to a dictionary of new column names
data_new_df = data_df.rename(columns={'id': 'ID',
                                      'first_name': 'First Name',
                                      'last_name': 'Last Name',
                                      'email': 'Email address',
                                      'gender': 'Sex',
                                      'uni_grad': 'University',
                                      'job_title': 'Career',
                                      'Income': 'Pay'})

data_new_df.head()
# Out:
#     ID First Name    Last Name                    Email address     Sex  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University              Career  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#        Pay
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 8. Re-order Columns

# %%
# Use a list of re-ordered column names to alter the column order of the original DataFrame
column_list = list(data_df.columns)
column_list

new_df = data_df[data_df.columns[[0, 3, 2, 1, 4, 7, 5]]]
new_df.head()
# Out:
#     id                            email    last_name first_name  gender  \
# 0  1.0  klenormand0@businessinsider.com    Lenormand    Keriann  Female
# 1  2.0              hrupke1@reuters.com        Rupke    Huntley    Male
# 2  3.0      gdalgarnowch2@microsoft.com  Dalgarnowch     Gorden    Male
# 3  4.0               cputten3@nymag.com          NaN     Cullie    Male
# 4  5.0       astrangman4@bravesites.com    Strangman      Ariel  Female
#
#     Income                                           uni_grad
# 0  58135.0                                  Aurora University
# 1  96053.0                      Osaka University of Economics
# 2  59196.0                                  Ludong University
# 3  88493.0  Université des Sciences et de la Technologie d...
# 4  89073.0                             Boise State University

# %% [markdown]
# ### 9. Create Additional Column

# %%
data_df['Income / 100'] = data_df['Income'] / 100
data_df
# Out:
#          id first_name    last_name                            email  gender  \
# 0       1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1       2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2       3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3       4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4       5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
# ..      ...        ...          ...                              ...     ...
# 995   996.0       Meta     Crumpton               mcrumptonrn@qq.com  Female
# 996   997.0      Gunar      Gilford             ggilfordro@yandex.ru    Male
# 997   998.0   Lucretia      Gurling                 lgurlingrp@de.vu  Female
# 998   999.0     Andrew         Yang             ayang@codedrills.com    Male
# 999  1000.0     Andrew         Yang             ayang@codedrills.com    Male
#
#                                               uni_grad              job_title  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# 4                               Boise State University        Project Manager
# ..                                                 ...                    ...
# 995               ECAM - Institut Supérieur Industriel       Registered Nurse
# 996                                  Smolny University      Marketing Manager
# 997                          Institut Teknologi Telkom  Software Engineer III
# 998              Rutgers University School of Business    Curriculum Engineer
# 999              Rutgers University School of Business    Curriculum Engineer
#
#       Income  Income / 100
# 0    58135.0        581.35
# 1    96053.0        960.53
# 2    59196.0        591.96
# 3    88493.0        884.93
# 4    89073.0        890.73
# ..       ...           ...
# 995  57060.0        570.60
# 996  76109.0        761.09
# 997  92115.0        921.15
# 998  60000.0        600.00
 63, 30, 29, 35, 55, 48, 42, 25, 32, 50, 60, 65, 30, 62, 63, 58, 31, 65, 41, 39, 56, 58, 28, 48, 47, 24, 28, 64, 54, 37, 57, 43, 48, 43, 44, 30, 45, 64, 41, 28, 43, 31, 23, 51, 64, 26, 50, 43, 61, 27, 37, 55, 51, 57, 65, 26, 65, 28, 44, 22, 34, 35, 58, 24]
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income  Income / 100  Age
# 0  58135.0        581.35   32
# 1  96053.0        960.53   48
# 2  59196.0        591.96   54
# 3  88493.0        884.93   23
# 4  89073.0        890.73   48

# %%
data_df['Age_copy'] = age
data_df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income  Income / 100  Age  Age_copy
# 0  58135.0        581.35   32        32
# 1  96053.0        960.53   48        48
# 2  59196.0        591.96   54        54
# 3  88493.0        884.93   23        23
# 4  89073.0        890.73   48        48

# %% [markdown]
# ### 10. Delete Columns

# %%
# Use the `drop` function to delete the newly created `Age_Copy` column
data_drop_df = data_df.drop(columns=['Age_copy'])
data_drop_df
# Out:
#          id first_name    last_name                            email  gender  \
# 0       1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1       2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2       3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3       4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4       5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
# ..      ...        ...          ...                              ...     ...
# 995   996.0       Meta     Crumpton               mcrumptonrn@qq.com  Female
# 996   997.0      Gunar      Gilford             ggilfordro@yandex.ru    Male
# 997   998.0   Lucretia      Gurling                 lgurlingrp@de.vu  Female
# 998   999.0     Andrew         Yang             ayang@codedrills.com    Male
# 999  1000.0     Andrew         Yang             ayang@codedrills.com    Male
#
#                                               uni_grad              job_title  \
# 0                                    Aurora University     Nurse Practicioner
# 1                        Osaka University of Economics        Project Manager
# 2                                    Ludong University     Environmental Tech
# 3    Université des Sciences et de la Technologie d...        Legal Assistant
# 4                               Boise State University        Project Manager
# ..                                                 ...                    ...
# 995               ECAM - Institut Supérieur Industriel       Registered Nurse
# 996                                  Smolny University      Marketing Manager
# 997                          Institut Teknologi Telkom  Software Engineer III
# 998              Rutgers University School of Business    Curriculum Engineer
# 999              Rutgers University School of Business    Curriculum Engineer
#
#       Income  Income / 100  Age
# 0    58135.0        581.35   32
# 1    96053.0        960.53   48
# 2    59196.0        591.96   54
# 3    88493.0        884.93   23
# 4    89073.0        890.73   48
# ..       ...           ...  ...
# 995  57060.0        570.60   22
# 996  76109.0        761.09   34
# 997  92115.0        921.15   35
# 998  60000.0        600.00   58
# 999  60000.0        600.00   24
#
# [1000 rows x 10 columns]

# %% [markdown]
# ### 11. Save Modified DataFrame to New CSV

# %%
# Save the DataFrame to the `Resources` folder

data_drop_df.to_csv('ThapaTest.csv')
