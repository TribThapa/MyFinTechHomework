# %% [markdown]
# # Students Do: Preventing credit card defaults with neural networks
#
# In this activity, you will train a neural network model to predict whether a credit card holder will default in the next month.
#
# The dataset provided contains `30,000` anonymous records of credit default status with `23` features columns and one binary target column entitled _DEFAULT_, where `1` represents a defaulted credit card.
#
# The `23` features include demographic info (age, gender, marital status, etc.), credit limit, past payment details, and other relevant information.
#
# You are tasked to create a neural network model to predict if a credit card holder will default.

# %%
# Initial imports
from path import Path
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ## Instructions
#
# 1. Load the data in a Pandas DataFrame.

# %%
# Read in data
cc_df = pd.read_csv(r'C:\Users\TribThapa\Desktop\Thapa\ResearchFellow\Courses\FinTech_Bootcamp_MonashUni2021\monu-mel-virt-fin-pt-05-2021-u-c\Activities\Week 14\1\03-Stu_CC_Default\Resources\cc_default.csv')

cc_df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...                     0          0          0         0       689
# 1      0  ...                  3272       3455       3261         0      1000
# 2      0  ...                 14331      14948      15549      1518      1500
# 3      0  ...                 28314      28959      29547      2000      2019
# 4      0  ...                 20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0         0        1
# 1      1000      1000         0      2000        1
# 2      1000      1000      1000      5000        0
# 3      1200      1100      1069      1000        0
# 4     10000      9000       689       679        0
#
# [5 rows x 24 columns]

# %% [markdown]
# 2. Define the features set `X` by including all the columns of the DataFrame except the `DEFAULT` column.

# %%
# Define features data
X = cc_df.drop("DEFAULT", axis=1)

X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  \
# 0     -2  ...        689                     0          0          0
# 1      0  ...       2682                  3272       3455       3261
# 2      0  ...      13559                 14331      14948      15549
# 3      0  ...      49291                 28314      28959      29547
# 4      0  ...      35835                 20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         0       689         0         0         0         0
# 1         0      1000      1000      1000         0      2000
# 2      1518      1500      1000      1000      1000      5000
# 3      2000      2019      1200      1100      1069      1000
# 4      2000     36681     10000      9000       689       679
#
# [5 rows x 23 columns]

# %% [markdown]
# 3. Create the target vector `y` by assigning the values of the `DEFAULT` column of the DataFrame.

# %%
# Define target data
y = cc_df[["DEFAULT"]]

y.head()
# Out:
#    DEFAULT
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0

# %% [markdown]
# 4. Create the training an testing sets using the `train_test_split` function from `sklearn`.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=78)

# %% [markdown]
# 5. Scale the features data using the `StandardScaler` from `sklearn`.

# %%
# Create the scaler instance
scaler = StandardScaler()

# %%
# Fit the scaler
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the features data
X_train_scaled = scaler.transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# 6. Create a neural network model with `23` inputs, one hidden layer with `69` units, and an output layer with a single output. Use the `relu` activation function for the first layer and `sigmoid` for the second layer.

# %%
# Create the sequential model
nn = Sequential()

# %%
# Define the model
number_hidden_nodes = 69

number_inputs = 23

nn.add(Dense(units=number_hidden_nodes,
             activation="relu",
             input_dim=number_inputs))

# %%
# Output layer
number_clases = 1

nn.add(Dense(units=number_clases,
             activation="sigmoid"))

# %% [markdown]
# 7. Compile the neural network model using the `binary_crossentropy` loss function, the `adam` optimizer, and `accuracy` as additional metric.

# %%
# Compile model
nn.compile(loss="binary_crossentropy",
           optimizer="adam",
           metrics=["accuracy"])

# %% [markdown]
# 8. Fit the model with `100` epochs.

# %%
# Fit the model
model = nn.fit(X_train_scaled,
               y_train,
               epochs=100)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4783 - accuracy: 0.8051: 0s - l
# Epoch 2/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4510 - accuracy: 0.8154
# Epoch 3/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4457 - accuracy: 0.8163: 0s - los
# Epoch 4/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4408 - accuracy: 0.8180
# Epoch 5/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4380 - accuracy: 0.8169
# Epoch 6/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4362 - accuracy: 0.8182
# Epoch 7/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4350 - accuracy: 0.8186
# Epoch 8/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4335 - accuracy: 0.8173
# Epoch 9/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4319 - accuracy: 0.8193
# Epoch 10/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4320 - accuracy: 0.8184
# Epoch 11/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4305 - accuracy: 0.8194
# Epoch 12/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4296 - accuracy: 0.8197
# Epoch 13/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4285 - accuracy: 0.8206
# Epoch 14/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4285 - accuracy: 0.8192
# Epoch 15/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4274 - accuracy: 0.8207
# Epoch 16/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4265 - accuracy: 0.8206
# Epoch 17/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4262 - accuracy: 0.8201
# Epoch 18/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4256 - accuracy: 0.8213
# Epoch 19/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4253 - accuracy: 0.8211
# Epoch 20/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4244 - accuracy: 0.8196
# Epoch 21/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4242 - accuracy: 0.8213
# Epoch 22/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4236 - accuracy: 0.8210
# Epoch 23/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.8212
# Epoch 24/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4232 - accuracy: 0.8216
# Epoch 25/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4220 - accuracy: 0.8212: 0s - loss: 0.4229 - accura
# Epoch 26/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4220 - accuracy: 0.8209
# Epoch 27/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4223 - accuracy: 0.8229
# Epoch 28/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4211 - accuracy: 0.8218: 0s - loss: 0.4174 - ac
# Epoch 29/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4208 - accuracy: 0.8226
# Epoch 30/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4206 - accuracy: 0.8234
# Epoch 31/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4199 - accuracy: 0.8214
# Epoch 32/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4198 - accuracy: 0.8223: 0s - loss: 0.4
# Epoch 33/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4184 - accuracy: 0.8218
# Epoch 34/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4192 - accuracy: 0.8218: 0s - loss: 0.4
# Epoch 35/100
# 704/704 [==============================] - ETA: 0s - loss: 0.4197 - accuracy: 0.82 - 2s 2ms/step - loss: 0.4189 - accuracy: 0.8227
# Epoch 36/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4187 - accuracy: 0.8224
# Epoch 37/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4180 - accuracy: 0.8229
# Epoch 38/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4176 - accuracy: 0.8245
# Epoch 39/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4175 - accuracy: 0.8244
# Epoch 40/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4177 - accuracy: 0.8240
# Epoch 41/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4174 - accuracy: 0.8228
# Epoch 42/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4172 - accuracy: 0.8227: 0s - loss: 0.414
# Epoch 43/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4167 - accuracy: 0.8249
# Epoch 44/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4167 - accuracy: 0.8226: 0s
# Epoch 45/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4158 - accuracy: 0.8246
# Epoch 46/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4160 - accuracy: 0.8231: 1s - loss:
# Epoch 47/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4158 - accuracy: 0.8237: 0s -
# Epoch 48/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4158 - accuracy: 0.8232
# Epoch 49/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4154 - accuracy: 0.8240
# Epoch 50/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4150 - accuracy: 0.8243: 0s - loss: 0.4
# Epoch 51/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4151 - accuracy: 0.8237
# Epoch 52/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4144 - accuracy: 0.8244
# Epoch 53/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4148 - accuracy: 0.8244
# Epoch 54/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.8238
# Epoch 55/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4144 - accuracy: 0.8235
# Epoch 56/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4132 - accuracy: 0.8262
# Epoch 57/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4131 - accuracy: 0.8248: 0s - loss: 0.4131 - accuracy: 0.
# Epoch 58/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4122 - accuracy: 0.8253
# Epoch 59/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4130 - accuracy: 0.8253
# Epoch 60/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4130 - accuracy: 0.8261
# Epoch 61/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4127 - accuracy: 0.8253
# Epoch 62/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4128 - accuracy: 0.8269
# Epoch 63/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4119 - accuracy: 0.8255: 1s - l
# Epoch 64/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4122 - accuracy: 0.8244
# Epoch 65/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4115 - accuracy: 0.8268
# Epoch 66/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4122 - accuracy: 0.8253
# Epoch 67/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4116 - accuracy: 0.8255
# Epoch 68/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4106 - accuracy: 0.8259
# Epoch 69/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8257
# Epoch 70/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4112 - accuracy: 0.8264: 0s - loss: 0.4098 - ac
# Epoch 71/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4108 - accuracy: 0.8253
# Epoch 72/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4102 - accuracy: 0.8270: 0s - loss: 0.4102 - accuracy: 0.82
# Epoch 73/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4103 - accuracy: 0.8264
# Epoch 74/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4109 - accuracy: 0.8256
# Epoch 75/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4107 - accuracy: 0.8268: 0s - loss: 0
# Epoch 76/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4103 - accuracy: 0.8267: 0s - loss: 0.4094 - accuracy
# Epoch 77/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4098 - accuracy: 0.8257: 0s - loss: 0.4109 - accuracy: 0.82 - ETA: 0s - loss: 0.4099 - accuracy:
# Epoch 78/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4099 - accuracy: 0.8256
# Epoch 79/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4094 - accuracy: 0.8254
# Epoch 80/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4087 - accuracy: 0.8264
# Epoch 81/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4101 - accuracy: 0.8260: 0s -
# Epoch 82/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4092 - accuracy: 0.8260: 0s - loss: 0.4083 - accuracy
# Epoch 83/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4099 - accuracy: 0.8265
# Epoch 84/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4095 - accuracy: 0.8263
# Epoch 85/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4092 - accuracy: 0.8269
# Epoch 86/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4087 - accuracy: 0.8255: 0s - loss: 0.4108 -
# Epoch 87/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4085 - accuracy: 0.8256
# Epoch 88/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4087 - accuracy: 0.8258: 0s - loss:
# Epoch 89/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4081 - accuracy: 0.8269
# Epoch 90/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4086 - accuracy: 0.8272
# Epoch 91/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4083 - accuracy: 0.8264: 0s - loss: 0.4086 - accuracy:
# Epoch 92/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4079 - accuracy: 0.8260
# Epoch 93/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4070 - accuracy: 0.8266
# Epoch 94/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4072 - accuracy: 0.8262
# Epoch 95/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4066 - accuracy: 0.8274: 0s - loss: 0.4100  - ETA: 0s - loss: 0.4066 - accu
# Epoch 96/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4073 - accuracy: 0.8263
# Epoch 97/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4067 - accuracy: 0.8269
# Epoch 98/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4063 - accuracy: 0.8272: 0s - los
# Epoch 99/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4070 - accuracy: 0.8270
# Epoch 100/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4071 - accuracy: 0.8260: 0s - loss: 0.4052

# %% [markdown]
# 9. Plot the loss function and accuracy.

# %%
# Create a DataFrame with the history dictionary
cc_df = pd.DataFrame(model.history,
                     index=range(1, len(model.history["loss"]) + 1))

cc_df.head()
# Out:
#        loss  accuracy
# 1  0.478344  0.805111
# 2  0.451015  0.815422
# 3  0.445686  0.816267
# 4  0.440836  0.818044
# 5  0.437976  0.816933

# %%
# Plot the loss
cc_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
cc_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10. Evaluate the model using testing data and the `evaluate` method.

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,
                                         y_test,
                                         verbose=2)

print(f"Loss: {model_loss}\n"
      f"Accuracy: {model_accuracy}")
# Out:
# 235/235 - 0s - loss: 0.4411 - accuracy: 0.8147
# Loss: 0.4410773813724518
# Accuracy: 0.8146666884422302

# %% [markdown]
# ## Challenge
#
# For this challenge section, you have to figure out how the model you created could be modified to improve the accuracy.
#
# 1. Review the Keras documentation about activation functions, and decide if there is anyone that could be used instead of `sigmoid`. https://keras.io/api/layers/activations/
#
# 2. Add a second hidden layer with `69` units and use a different activation function than `sigmoid`.
#
# 3. Change any other parameter that you believe could improve the model's accuracy.
#
# 4. Evaluate the model's accuracy and loss and write down your conclusions.

# %%
# Create the sequential model
neuron = Sequential()

# %%
# First layer. Define the model
number_hidden_nodes = 69

number_inputs = 23

neuron.add(Dense(units=number_hidden_nodes,
                 activation="softmax",
                 input_dim=number_inputs))

# %%
# Second layer.
number_hidden_nodes = 69

number_inputs = 23

neuron.add(Dense(units=number_hidden_nodes,
                 activation="softmax",
                 input_dim=number_inputs))

# %%
# Output layer
number_classes = 1

neuron.add(Dense(units=number_classes, 
                 activation="softmax"))

# %%
# Model summary
neuron.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 69)                1656
# _________________________________________________________________
# dense_3 (Dense)              (None, 69)                4830
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 70
# =================================================================
# Total params: 6,556
# Trainable params: 6,556
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
neuron.compile(loss="binary_crossentropy",
               optimizer="adam",
               metrics=["accuracy"])

# %%
# Fit the model
model2 = neuron.fit(X_train_scaled,
                    y_train,
                    epochs=100)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.5782 - accuracy: 0.2224
# Epoch 2/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4959 - accuracy: 0.2224
# Epoch 3/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4649 - accuracy: 0.2224: 0s -
# Epoch 4/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4520 - accuracy: 0.2224
# Epoch 5/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4490 - accuracy: 0.2224: 0s - loss: 0.4474 - accuracy:
# Epoch 6/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4464 - accuracy: 0.2224
# Epoch 7/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4436 - accuracy: 0.2224
# Epoch 8/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4414 - accuracy: 0.2224: 0s - loss: 0.4413 - accu - ETA: 0s - loss: 0.4403
# Epoch 9/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4396 - accuracy: 0.2224
# Epoch 10/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4380 - accuracy: 0.2224: 0s - loss: 0.4381 - accuracy: 0.
# Epoch 11/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4364 - accuracy: 0.2224
# Epoch 12/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4351 - accuracy: 0.2224
# Epoch 13/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4338 - accuracy: 0.2224
# Epoch 14/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4325 - accuracy: 0.2224: 0s - loss: 0.4321 -
# Epoch 15/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4313 - accuracy: 0.2224
# Epoch 16/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4300 - accuracy: 0.2224
# Epoch 17/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4291 - accuracy: 0.2224
# Epoch 18/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4281 - accuracy: 0.2224
# Epoch 19/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4272 - accuracy: 0.2224
# Epoch 20/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4266 - accuracy: 0.2224
# Epoch 21/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4259 - accuracy: 0.2224
# Epoch 22/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4251 - accuracy: 0.2224
# Epoch 23/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4245 - accuracy: 0.2224
# Epoch 24/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4242 - accuracy: 0.2224: 0s - loss: 0.4232 - accuracy: 0.
# Epoch 25/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4234 - accuracy: 0.2224
# Epoch 26/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4230 - accuracy: 0.2224
# Epoch 27/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4223 - accuracy: 0.2224
# Epoch 28/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4220 - accuracy: 0.2224
# Epoch 29/100
# 704/704 [==============================] - 3s 4ms/step - loss: 0.4214 - accuracy: 0.2224
# Epoch 30/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4210 - accuracy: 0.2224
# Epoch 31/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4206 - accuracy: 0.2224: 0s - loss: 0.4201 - accuracy: 0.22
# Epoch 32/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4200 - accuracy: 0.2224
# Epoch 33/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4197 - accuracy: 0.2224
# Epoch 34/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4192 - accuracy: 0.2224: 0s - loss: - ETA: 0s - loss: 0
# Epoch 35/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4189 - accuracy: 0.2224
# Epoch 36/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4185 - accuracy: 0.2224
# Epoch 37/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4183 - accuracy: 0.2224: 0s - loss: 0.4183 - accuracy: 0.22
# Epoch 38/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4179 - accuracy: 0.2224
# Epoch 39/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4176 - accuracy: 0.2224: 0s - loss: 0.4121 - accura - ETA: 0s - loss: 0.4134 -
# Epoch 40/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4170 - accuracy: 0.2224
# Epoch 41/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4168 - accuracy: 0.2224
# Epoch 42/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4164 - accuracy: 0.2224
# Epoch 43/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4160 - accuracy: 0.2224
# Epoch 44/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4158 - accuracy: 0.2224
# Epoch 45/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4155 - accuracy: 0.2224
# Epoch 46/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4150 - accuracy: 0.2224
# Epoch 47/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4147 - accuracy: 0.2224
# Epoch 48/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4143 - accuracy: 0.2224
# Epoch 49/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4139 - accuracy: 0.2224
# Epoch 50/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4135 - accuracy: 0.2224: 0s - loss: 0.4151 - accura
# Epoch 51/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4129 - accuracy: 0.2224: 0s - loss: 0.4129 - accuracy: 0.22
# Epoch 52/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4128 - accuracy: 0.2224: 0s - loss: 0.4103 - accuracy
# Epoch 53/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4126 - accuracy: 0.2224
# Epoch 54/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4121 - accuracy: 0.2224
# Epoch 55/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4121 - accuracy: 0.2224
# Epoch 56/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.2224
# Epoch 57/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4113 - accuracy: 0.2224
# Epoch 58/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4109 - accuracy: 0.2224
# Epoch 59/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4107 - accuracy: 0.2224
# Epoch 60/100
# 704/704 [==============================] - ETA: 0s - loss: 0.4089 - accuracy: 0.22 - 1s 2ms/step - loss: 0.4102 - accuracy: 0.2224
# Epoch 61/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.2224
# Epoch 62/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4098 - accuracy: 0.2224
# Epoch 63/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4095 - accuracy: 0.2224
# Epoch 64/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4093 - accuracy: 0.2224: 0s - loss: 0.4099 - accuracy
# Epoch 65/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4088 - accuracy: 0.2224
# Epoch 66/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4085 - accuracy: 0.2224
# Epoch 67/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4083 - accuracy: 0.2224
# Epoch 68/100
# 704/704 [==============================] - ETA: 0s - loss: 0.4085 - accuracy: 0.22 - 2s 2ms/step - loss: 0.4078 - accuracy: 0.2224
# Epoch 69/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4075 - accuracy: 0.2224
# Epoch 70/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4073 - accuracy: 0.2224
# Epoch 71/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4068 - accuracy: 0.2224
# Epoch 72/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4066 - accuracy: 0.2224: 0s - loss: 0.4047 - accuracy:
# Epoch 73/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4064 - accuracy: 0.2224: 1s - loss: 0.4178 - accuracy:  - ETA: 1s
# Epoch 74/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4061 - accuracy: 0.2224: 0s - loss:
# Epoch 75/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4058 - accuracy: 0.2224: 0s - loss: 0.4050 - accura
# Epoch 76/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4053 - accuracy: 0.2224
# Epoch 77/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4051 - accuracy: 0.2224
# Epoch 78/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4050 - accuracy: 0.2224
# Epoch 79/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4043 - accuracy: 0.2224
# Epoch 80/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4043 - accuracy: 0.2224
# Epoch 81/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4040 - accuracy: 0.2224
# Epoch 82/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4034 - accuracy: 0.2224: 0s - loss: 0.4041 - accuracy:
# Epoch 83/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4035 - accuracy: 0.2224
# Epoch 84/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4031 - accuracy: 0.2224
# Epoch 85/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4027 - accuracy: 0.2224
# Epoch 86/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4023 - accuracy: 0.2224
# Epoch 87/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4022 - accuracy: 0.2224
# Epoch 88/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4021 - accuracy: 0.2224
# Epoch 89/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4015 - accuracy: 0.2224: 0s - loss: 0.3996 - accura
# Epoch 90/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4013 - accuracy: 0.2224: 0s - l
# Epoch 91/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4007 - accuracy: 0.2224: 1s
# Epoch 92/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.2224
# Epoch 93/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4003 - accuracy: 0.2224
# Epoch 94/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4001 - accuracy: 0.2224
# Epoch 95/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4001 - accuracy: 0.2224: 0s - loss:
# Epoch 96/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.2224
# Epoch 97/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.2224
# Epoch 98/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.2224
# Epoch 99/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3985 - accuracy: 0.2224
# Epoch 100/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3985 - accuracy: 0.2224

# %%
# Evaluate the model fit with linear dummy data
model2_loss, model2_accuracy = neuron.evaluate(X_test_scaled,
                                               y_test,
                                               verbose=2)

print(f"Loss: {model2_loss} \n"
      f"Accuracy: {model2_accuracy}")
# Out:
# 235/235 - 1s - loss: 0.4402 - accuracy: 0.2177
# Loss: 0.4402184784412384
# Accuracy: 0.21773333847522736

# %% [markdown]
# ### Conclusions
#
# My changes led to a huge drop in accuracy and increase in loss of data - so not a good choice! :(
