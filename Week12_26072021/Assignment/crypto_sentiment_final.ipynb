# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi.newsapi_client import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\TribThapa\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
news_api_key = os.getenv("NEWS_API_KEY")

print(f"News API Key type: {type(news_api_key)}")
# Out:
# News API Key type: <class 'str'>

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=news_api_key)

newsapi

# %%
# Fetch the Bitcoin news articles
btc_news = newsapi.get_everything(q="bitcoin",
                                  language='en')

# %%
# Quick summary of BTC news
print(f"Here is an example of BTC news: \n"
      f"\n"
      f"{btc_news['articles'][0]}")
print()
print(f"The total number of articles received is {btc_news['totalResults']}")
# Out:
# Here is an example of BTC news:
#
# {'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Khari Johnson', 'title': 'Why Not Use Self-Driving Cars as Supercomputers?', 'description': 'Autonomous vehicles use the equivalent of 200 laptops to get around. Some want to tap that computing power to decode viruses or mine bitcoin.', 'url': 'https://www.wired.com/story/use-self-driving-cars-supercomputers/', 'urlToImage': 'https://media.wired.com/photos/60f081b4c147fe7a1a367362/191:100/w_1280,c_limit/Business-Autonomous-Vehicles-Supercomputers-1201885684.jpg', 'publishedAt': '2021-07-19T11:00:00Z', 'content': 'Like Dogecoin devotees, the mayor of Reno, and the leaders of El Salvador, Aldo Baoicchi is convinced cryptocurrency is the future. The CEO and founder of Canadian scooter maker Daymak believes this … [+4116 chars]'}
#
# The total number of articles received is 7751

# %%
# Fetch the Ethereum news articles
eth_news = newsapi.get_everything(q="ethereum",
                                  language="en")

# %%
# Quick summary of ETH news
print(f"Here is an example of ETH news: \n"
      f"\n"
      f"{eth_news['articles'][0]}")
print()
print(f"The total number of articles received is {eth_news['totalResults']}")
# Out:
# Here is an example of ETH news:
#
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'}, 'author': 'Connie Loizos', 'title': 'Crypto investors like Terraform Labs so much, they’re committing $150 million to its ‘ecosystem’', 'description': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote about in May. Often, these technologies are seen as so prom…', 'url': 'http://techcrunch.com/2021/07/16/crypto-investors-like-terraform-labs-so-much-theyre-committing-150-million-to-its-ecosystem/', 'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1174590894.jpg?w=667', 'publishedAt': '2021-07-16T16:00:55Z', 'content': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]'}
#
# The total number of articles received is 2439

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

# Get sentiment and append to list
for article in btc_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        positive = sentiment["pos"]
        negative = sentiment["neg"]
        neutral = sentiment["neu"]
        
        btc_sentiments.append({"text": text,
                               "compound": compound,
                               "positive": positive,
                               "negative": negative,
                               "neutral": neutral})
    except AttributError:
        pass

# Create sentiment dataframe
btc_sentiments_df = pd.DataFrame(btc_sentiments)

# Show results
print("Below is what the BTC sentiments table looks like:")
print()
display(btc_sentiments_df.head())
print()
print("Below is the description of the BTC sentiments table:")
print()
print(btc_sentiments_df.describe())
# Out:
# Below is what the BTC sentiments table looks like:
#                                                 text  compound  positive  \
# 0  Like Dogecoin devotees, the mayor of Reno, and...    0.6908     0.178
# 1  Filed under:\r\nThe supply chain attack has re...   -0.5719     0.111
# 2  image copyrightGetty Images\r\nThe gang behind...   -0.6124     0.000
# 3  To get a roundup of TechCrunchs biggest and mo...    0.6240     0.127
# 4  While retail investors grew more comfortable b...    0.7264     0.164
#
#    negative  neutral
# 0     0.000    0.822
# 1     0.184    0.705
# 2     0.143    0.857
# 3     0.000    0.873
# 4     0.000    0.836
# Below is the description of the BTC sentiments table:
#
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.014545   0.055900   0.051300   0.892800
# std     0.471377   0.060072   0.091597   0.107686
# min    -0.827100   0.000000   0.000000   0.653000
# 25%    -0.119175   0.000000   0.000000   0.836000
# 50%     0.000000   0.048500   0.000000   0.910500
# 75%     0.315000   0.092500   0.078250   1.000000
# max     0.726400   0.178000   0.287000   1.000000

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

# Get sentiment and append to list
for article in eth_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        positive = sentiment["pos"]
        negative = sentiment["neg"]
        neutral = sentiment["neu"]
        
        eth_sentiments.append({"text": text,
                               "compound": compound,
                               "positive": positive,
                               "negative": negative,
                               "neutral": neutral})
    except AttributError:
        pass

# Create sentiment dataframe
eth_sentiments_df = pd.DataFrame(eth_sentiments)

# Show results
print("Below is what the ETH sentiments table looks like:")
print()
display(eth_sentiments_df.head())
print()
print("Below is the description of the ETH sentiments table:")
print()
print(eth_sentiments_df.describe())
# Out:
# Below is what the ETH sentiments table looks like:
#                                                 text  compound  positive  \
# 0  There are many blockchain platforms competing ...    0.3612     0.075
# 1  Blockchain infrastructure startups are heating...   -0.2411     0.000
# 2  While retail investors grew more comfortable b...    0.7264     0.164
# 3  Cryptocurrencies spiked Monday after Amazon li...    0.3400     0.105
# 4  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612     0.110
#
#    negative  neutral
# 0     0.000    0.925
# 1     0.061    0.939
# 2     0.000    0.836
# 3     0.000    0.895
# 4     0.041    0.849
# Below is the description of the ETH sentiments table:
#
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.247720   0.073250   0.015500   0.911250
# std     0.326828   0.073203   0.028127   0.078638
# min    -0.340000   0.000000   0.000000   0.782000
# 25%     0.000000   0.000000   0.000000   0.842750
# 50%     0.295000   0.077500   0.000000   0.922500
# 75%     0.528675   0.149250   0.010250   1.000000
# max     0.771700   0.194000   0.072000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: ETH has a greater mean positive score (0.073250) when compared to BTC (0.055900).
#
# <br/><br/>
#
# Q: Which coin had the highest compound score?
#
# A: ETH has a higher compound score of 0.771700 when compared to BTC (0.726400). The compound score is the sum of positive, negative & neutral scores which is then normalized between -1 (most extreme negative) and +1 (most extreme positive).
#
# The closer the Compound score is to +1, the higher the positivity of the text.
#
# <br/><br/>
#
# Q. Which coin had the highest positive score?
#
# A: ETH has the highest positive score of 0.194000 when compared to BTC (0.178000).

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = ["the", "will", "of", "with"]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words_tokenized = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words_tokenized]
   
    # Convert the words to lowercase
    words_lowercase = [word.lower() for word in lem]
    
    # Remove the stop words
    words_str = ' '.join(words_lowercase)
            
    tokens = [word for word in words_lowercase if word not in sw.union(sw_addons)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc_tokens_list = []

for text in btc_sentiments_df['text']:
    
    tokenized_text = tokenizer(text)
    
    btc_tokens_list.append(tokenized_text)

# %%
btc_sentiments_df["tokens"] = btc_tokens_list

btc_sentiments_df = btc_sentiments_df[["compound", "positive", "negative", "neutral", "text", "tokens"]] 

btc_sentiments_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0    0.6908     0.178     0.000    0.822
# 1   -0.5719     0.111     0.184    0.705
# 2   -0.6124     0.000     0.143    0.857
# 3    0.6240     0.127     0.000    0.873
# 4    0.7264     0.164     0.000    0.836
#
#                                                 text  \
# 0  Like Dogecoin devotees, the mayor of Reno, and...
# 1  Filed under:\r\nThe supply chain attack has re...
# 2  image copyrightGetty Images\r\nThe gang behind...
# 3  To get a roundup of TechCrunchs biggest and mo...
# 4  While retail investors grew more comfortable b...
#
#                                               tokens
# 0  [like, dogecoin, devotee, mayor, reno, leader,...
# 1  [filed, underthe, supply, chain, attack, ha, r...
# 2  [image, copyrightgetty, imagesthe, gang, behin...
# 3  [get, roundup, techcrunchs, biggest, important...
# 4  [retail, investor, grew, comfortable, buying, ...

# %%
# Create a new tokens list for Bitcoin across all texts
btc_text = str(list(btc_sentiments_df['text']))

btc_tokens = tokenizer(btc_text)

print(f"Here is an example of BTC word tokens: {btc_tokens[:50]}")
print()
print(f"The total number of BTC word tokens are: {len(btc_tokens)}")
# Out:
# Here is an example of BTC word tokens: ['like', 'dogecoin', 'devotee', 'mayor', 'reno', 'leader', 'el', 'salvador', 'aldo', 'baoicchi', 'convinced', 'cryptocurrency', 'future', 'ceo', 'founder', 'canadian', 'scooter', 'maker', 'daymak', 'belief', 'char', 'filed', 'underrnthe', 'supply', 'chain', 'attack', 'ha', 'reached', 'thousand', 'organizationsrnillustration', 'alex', 'castro', 'vergernthree', 'day', 'ransomware', 'attacker', 'started', 'holiday', 'weekend', 'comprom', 'char', 'image', 'copyrightgetty', 'imagesrnthe', 'gang', 'behind', 'colossal', 'ransomware', 'attack', 'ha']
#
# The total number of BTC word tokens are: 386

# %%
# Create a new tokens column for Ethereum
eth_tokens_list = []

for text in eth_sentiments_df['text']:
    
    tokenized_text = tokenizer(text)
    
    eth_tokens_list.append(tokenized_text)

# %%
eth_sentiments_df["tokens"] = eth_tokens_list

eth_sentiments_df = eth_sentiments_df[["compound", "positive", "negative", "neutral", "text", "tokens"]] 

eth_sentiments_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0    0.3612     0.075     0.000    0.925
# 1   -0.2411     0.000     0.061    0.939
# 2    0.7264     0.164     0.000    0.836
# 3    0.3400     0.105     0.000    0.895
# 4    0.3612     0.110     0.041    0.849
#
#                                                 text  \
# 0  There are many blockchain platforms competing ...
# 1  Blockchain infrastructure startups are heating...
# 2  While retail investors grew more comfortable b...
# 3  Cryptocurrencies spiked Monday after Amazon li...
# 4  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...
#
#                                               tokens
# 0  [many, blockchain, platform, competing, invest...
# 1  [blockchain, infrastructure, startup, heating,...
# 2  [retail, investor, grew, comfortable, buying, ...
# 3  [cryptocurrencies, spiked, monday, amazon, lis...
# 4  [bitcoin, ethereumyuriko, nakaoether, overtook...

# %%
# Create a new tokens column for Ethereum
eth_text = str(list(eth_sentiments_df['text']))

eth_tokens = tokenizer(eth_text)

print(f"Here is an example of ETH word tokens: {eth_tokens[:10]}")
print()
print(f"The total number of ETH word tokens are: {len(eth_tokens)}")
# Out:
# Here is an example of ETH word tokens: ['many', 'blockchain', 'platform', 'competing', 'investor', 'developer', 'attention', 'right', 'big', 'daddy']
#
# The total number of ETH word tokens are: 379

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Bitcoin Counter
btc_word_count = Counter(btc_tokens)

print(f"Here's the word count: \n"
      f"\n"
      f"{dict(btc_word_count)}")
print()
print(f"Here's the most commont: {dict(btc_word_count.most_common(10))}")
# Out:
# Here's the word count:
#
# {'like': 2, 'dogecoin': 2, 'devotee': 1, 'mayor': 1, 'reno': 1, 'leader': 1, 'el': 1, 'salvador': 1, 'aldo': 1, 'baoicchi': 1, 'convinced': 1, 'cryptocurrency': 3, 'future': 1, 'ceo': 1, 'founder': 1, 'canadian': 1, 'scooter': 1, 'maker': 2, 'daymak': 1, 'belief': 1, 'char': 20, 'filed': 1, 'underrnthe': 1, 'supply': 1, 'chain': 1, 'attack': 7, 'ha': 4, 'reached': 1, 'thousand': 1, 'organizationsrnillustration': 1, 'alex': 1, 'castro': 1, 'vergernthree': 1, 'day': 2, 'ransomware': 4, 'attacker': 1, 'started': 1, 'holiday': 1, 'weekend': 1, 'comprom': 1, 'image': 2, 'copyrightgetty': 1, 'imagesrnthe': 1, 'gang': 2, 'behind': 1, 'colossal': 1, 'demanded': 2, 'paid': 1, 'bitcoin': 14, 'return': 1, 'universal': 1, 'decryptor': 1, 'say': 1, 'unlock': 1, 'file': 1, 'get': 3, 'roundup': 1, 'techcrunchs': 1, 'biggest': 1, 'important': 1, 'story': 1, 'delivered': 1, 'inbox': 1, 'every': 1, 'pm': 1, 'pdt': 1, 'subscribe': 1, 'herernhello': 1, 'welcome': 1, 'daily': 1, 'crunch': 1, 'july': 3, 'retail': 1, 'investor': 1, 'grew': 1, 'comfortable': 1, 'buying': 1, 'cryptocurrencies': 2, 'ethereum': 2, 'decentralized': 1, 'application': 1, 'world': 2, 'still': 1, 'lot': 1, 'work': 1, 'come': 1, 'onboarding': 1, 'longtime': 1, 'techcrunch': 2, 'reader': 1, 'know': 1, 'well': 2, 'michael': 1, 'arrington': 1, 'cofounded': 1, 'crunchbase': 1, 'venture': 1, 'fund': 1, 'crunchfund': 1, 'wa': 3, 'later': 1, 'renamed': 1, 'tuesday': 1, 'capital': 1, 'arringto': 1, 'singapore': 1, 'reuters': 7, 'broke': 1, 'wednesday': 1, 'headed': 1, 'another': 1, 'attempt': 1, 'breaking': 1, 'monthslong': 1, 'range': 1, 'short': 1, 'seller': 1, 'bailed': 1, 'trader': 1, 'drew': 1, 'confidence': 1, 'fr': 1, 'staffrnfile': 2, 'photo': 2, 'representations': 3, 'seen': 6, 'illustration': 7, 'picture': 1, 'taken': 6, 'june': 3, 'reutersedgar': 1, 'suillustrationfile': 1, 'photornreuters': 1, 'ro': 1, 'representation': 4, 'virtual': 5, 'currency': 5, 'front': 5, 'stock': 4, 'graph': 4, 'march': 1, 'reutersdado': 7, 'ruvicillustrationlondon': 1, 'youre': 1, 'bitcoi': 1, 'james': 1, 'martincnetrna': 1, 'uk': 1, 'man': 1, 'arrested': 1, 'spain': 1, 'alleged': 1, 'role': 1, 'massive': 1, 'hack': 1, 'highprofile': 1, 'twitter': 1, 'account': 1, 'targeted': 1, 'politiciansxaand': 1, 'celebrity': 1, 'us': 1, 'department': 1, 'justi': 1, 'takenmay': 1, 'ruvicillustrationjuly': 1, 'dropped': 1, 'november': 2, 'ruvicillustrationsingapore': 1, 'reco': 1, 'ruvicillustrationrnsingapore': 1, 'ripple': 1, 'litecoin': 1, 'placed': 1, 'pc': 1, 'motherboard': 1, 'ruvicillustrationwashington': 1, 'ju': 1, 'ruvicillustrationrnwelcome': 1, 'things': 1, 'opening': 1, 'bell': 1, 'forwarded': 1, 'sign': 1, 'herernmarkets': 1, 'insider': 1, 'selling': 1, 'first': 2, 'nfts': 1, 'detail': 1, 'herernlets': 1, 'opinions': 1, 'expressed': 1, 'entrepreneur': 1, 'contributor': 1, 'ownrni': 1, 'launched': 2, 'business': 3, 'three': 1, 'decade': 1, 'ago': 2, 'recent': 1, 'six': 1, 'month': 1, 'ive': 1, 'invested': 1, 'dozen': 1, 'si': 1, 'tesla': 2, 'logo': 1, 'february': 1, 'ruvicjuly': 1, 'electriccar': 1, 'inc': 1, 'tslao': 1, 'w': 1, 'fueled': 1, 'covid': 1, 'pandemic': 1, 'turbulence': 1, 'become': 2, 'major': 1, 'money': 1, 'earner': 1, 'cybercriminals': 1, 'number': 1, 'rising': 1, 'rnthese': 1, 'fileencrypting': 1, 'continu': 1, 'captionthe': 1, 'group': 1, 'recently': 1, 'huge': 1, 'ransom': 1, 'targeting': 1, 'firm': 1, 'kaseyarnwebsites': 1, 'russianlinked': 1, 'blamed': 1, 'hundred': 1, 'circle': 2, 'announced': 1, 'plan': 1, 'public': 1, 'company': 2, 'merge': 1, 'concord': 1, 'acquisition': 1, 'corp': 1, 'spac': 1, 'better': 1, 'known': 1, 'one': 1, 'founding': 1, 'member': 1, 'th': 1}
#
# Here's the most commont: {'char': 20, 'bitcoin': 14, 'attack': 7, 'reuters': 7, 'illustration': 7, 'reutersdado': 7, 'seen': 6, 'taken': 6, 'virtual': 5, 'currency': 5}

# %%
# Generate the Bitcoin N-grams where N=2
btc_bigrams = Counter(ngrams(btc_tokens,n=2))

print(f"Here BTC bigrams: \n"
      f"\n"
      f"{dict(btc_bigrams)}")
# Out:
# Here BTC bigrams:
#
# {('like', 'dogecoin'): 1, ('dogecoin', 'devotee'): 1, ('devotee', 'mayor'): 1, ('mayor', 'reno'): 1, ('reno', 'leader'): 1, ('leader', 'el'): 1, ('el', 'salvador'): 1, ('salvador', 'aldo'): 1, ('aldo', 'baoicchi'): 1, ('baoicchi', 'convinced'): 1, ('convinced', 'cryptocurrency'): 1, ('cryptocurrency', 'future'): 1, ('future', 'ceo'): 1, ('ceo', 'founder'): 1, ('founder', 'canadian'): 1, ('canadian', 'scooter'): 1, ('scooter', 'maker'): 1, ('maker', 'daymak'): 1, ('daymak', 'belief'): 1, ('belief', 'char'): 1, ('char', 'filed'): 1, ('filed', 'underrnthe'): 1, ('underrnthe', 'supply'): 1, ('supply', 'chain'): 1, ('chain', 'attack'): 1, ('attack', 'ha'): 2, ('ha', 'reached'): 1, ('reached', 'thousand'): 1, ('thousand', 'organizationsrnillustration'): 1, ('organizationsrnillustration', 'alex'): 1, ('alex', 'castro'): 1, ('castro', 'vergernthree'): 1, ('vergernthree', 'day'): 1, ('day', 'ransomware'): 1, ('ransomware', 'attacker'): 1, ('attacker', 'started'): 1, ('started', 'holiday'): 1, ('holiday', 'weekend'): 1, ('weekend', 'comprom'): 1, ('comprom', 'char'): 1, ('char', 'image'): 2, ('image', 'copyrightgetty'): 1, ('copyrightgetty', 'imagesrnthe'): 1, ('imagesrnthe', 'gang'): 1, ('gang', 'behind'): 1, ('behind', 'colossal'): 1, ('colossal', 'ransomware'): 1, ('ransomware', 'attack'): 2, ('ha', 'demanded'): 1, ('demanded', 'paid'): 1, ('paid', 'bitcoin'): 1, ('bitcoin', 'return'): 1, ('return', 'universal'): 1, ('universal', 'decryptor'): 1, ('decryptor', 'say'): 1, ('say', 'unlock'): 1, ('unlock', 'file'): 1, ('file', 'char'): 1, ('char', 'get'): 1, ('get', 'roundup'): 1, ('roundup', 'techcrunchs'): 1, ('techcrunchs', 'biggest'): 1, ('biggest', 'important'): 1, ('important', 'story'): 1, ('story', 'delivered'): 1, ('delivered', 'inbox'): 1, ('inbox', 'every'): 1, ('every', 'day'): 1, ('day', 'pm'): 1, ('pm', 'pdt'): 1, ('pdt', 'subscribe'): 1, ('subscribe', 'herernhello'): 1, ('herernhello', 'welcome'): 1, ('welcome', 'daily'): 1, ('daily', 'crunch'): 1, ('crunch', 'july'): 1, ('july', 'char'): 1, ('char', 'retail'): 1, ('retail', 'investor'): 1, ('investor', 'grew'): 1, ('grew', 'comfortable'): 1, ('comfortable', 'buying'): 1, ('buying', 'cryptocurrencies'): 1, ('cryptocurrencies', 'like'): 1, ('like', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 2, ('ethereum', 'decentralized'): 1, ('decentralized', 'application'): 1, ('application', 'world'): 1, ('world', 'still'): 1, ('still', 'ha'): 1, ('ha', 'lot'): 1, ('lot', 'work'): 1, ('work', 'come'): 1, ('come', 'onboarding'): 1, ('onboarding', 'char'): 1, ('char', 'longtime'): 1, ('longtime', 'techcrunch'): 1, ('techcrunch', 'reader'): 1, ('reader', 'know'): 1, ('know', 'well'): 1, ('well', 'michael'): 1, ('michael', 'arrington'): 1, ('arrington', 'cofounded'): 1, ('cofounded', 'techcrunch'): 1, ('techcrunch', 'crunchbase'): 1, ('crunchbase', 'well'): 1, ('well', 'venture'): 1, ('venture', 'fund'): 1, ('fund', 'crunchfund'): 1, ('crunchfund', 'wa'): 1, ('wa', 'later'): 1, ('later', 'renamed'): 1, ('renamed', 'tuesday'): 1, ('tuesday', 'capital'): 1, ('capital', 'arringto'): 1, ('arringto', 'char'): 1, ('char', 'singapore'): 1, ('singapore', 'july'): 1, ('july', 'reuters'): 2, ('reuters', 'bitcoin'): 3, ('bitcoin', 'broke'): 1, ('broke', 'wednesday'): 1, ('wednesday', 'headed'): 1, ('headed', 'another'): 1, ('another', 'attempt'): 1, ('attempt', 'breaking'): 1, ('breaking', 'monthslong'): 1, ('monthslong', 'range'): 1, ('range', 'short'): 1, ('short', 'seller'): 1, ('seller', 'bailed'): 1, ('bailed', 'trader'): 1, ('trader', 'drew'): 1, ('drew', 'confidence'): 1, ('confidence', 'fr'): 1, ('fr', 'char'): 1, ('char', 'reuters'): 2, ('reuters', 'staffrnfile'): 2, ('staffrnfile', 'photo'): 2, ('photo', 'representations'): 1, ('representations', 'bitcoin'): 1, ('bitcoin', 'cryptocurrency'): 1, ('cryptocurrency', 'seen'): 1, ('seen', 'illustration'): 1, ('illustration', 'picture'): 1, ('picture', 'taken'): 1, ('taken', 'june'): 2, ('june', 'reutersedgar'): 1, ('reutersedgar', 'suillustrationfi ...

# %%
# Ethereum Counter
eth_word_count = Counter(eth_tokens)

print(f"Here's the word count: \n"
      f"\n"
      f"{dict(eth_word_count)}")
print()
print(f"Here's the most commont: {dict(eth_word_count.most_common(10))}")
# Out:
# Here's the word count:
#
# {'many': 1, 'blockchain': 4, 'platform': 2, 'competing': 1, 'investor': 3, 'developer': 2, 'attention': 1, 'right': 1, 'big': 1, 'daddy': 1, 'ethereum': 13, 'socalled': 2, 'killers': 1, 'like': 3, 'solana': 1, 'wrote': 1, 'char': 20, 'infrastructure': 1, 'startup': 1, 'heating': 1, 'industry': 2, 'fervor': 1, 'brings': 1, 'user': 2, 'space': 1, 'still': 2, 'feel': 1, 'extremely': 1, 'young': 1, 'despite': 1, 'heavy': 1, 'institutional': 2, 'embrace': 1, 'crypto': 3, 'retail': 1, 'grew': 1, 'comfortable': 1, 'buying': 1, 'cryptocurrencies': 3, 'bitcoin': 8, 'decentralized': 2, 'application': 1, 'world': 4, 'ha': 4, 'lot': 1, 'work': 2, 'come': 1, 'onboarding': 1, 'spiked': 1, 'monday': 2, 'amazon': 1, 'listed': 1, 'open': 2, 'job': 1, 'digital': 1, 'currency': 2, 'product': 2, 'leadxarnamazon': 1, 'known': 1, 'plummeting': 1, 'stock': 2, 'wouldbe': 1, 'rival': 1, 'whenever': 1, 'rumor': 1, 'swirl': 1, 'ethereumrnyuriko': 1, 'nakaornether': 1, 'overtook': 1, 'number': 1, 'active': 1, 'address': 1, 'network': 6, 'friday': 1, 'sign': 1, 'demand': 1, 'faltering': 1, 'biggest': 1, 'cryptocurrency': 8, 'co': 1, 'anthony': 1, 'di': 1, 'iorio': 1, 'cofounder': 1, 'say': 1, 'done': 1, 'partially': 1, 'personal': 2, 'safety': 1, 'concern': 1, 'report': 1, 'bloomberg': 1, 'story': 1, 'shared': 1, 'slashdot': 1, 'representations': 2, 'placed': 1, 'pc': 1, 'motherboard': 1, 'illustration': 3, 'taken': 2, 'june': 2, 'reutersdado': 2, 'ruvicillustrationnew': 1, 'york': 1, 'july': 1, 'reuters': 3, 'secondla': 1, 'ether': 2, 'holder': 2, 'staked': 2, 'billion': 3, 'worth': 2, 'excitement': 2, 'build': 1, 'around': 1, 'overhaul': 1, 'system': 1, 'potential': 1, 'growth': 1, 'staki': 1, 'networkrnphotothekgetty': 1, 'imagesrnether': 1, 'session': 1, 'transform': 1, 'available': 1, 'ondemand': 1, 'watch': 1, 'nowrnlivepeer': 1, 'raised': 1, 'million': 1, 'video': 1, 'transcoding': 1, 'built': 1, 'blockchainxaits': 1, 'ano': 1, 'article': 2, 'wa': 2, 'translated': 2, 'spanish': 2, 'edition': 2, 'using': 2, 'ai': 2, 'technology': 2, 'errors': 2, 'may': 3, 'exist': 2, 'due': 2, 'processrnthe': 2, 'firm': 1, 'xoy': 1, 'capital': 1, 'based': 1, 'guadalajara': 1, 'jalisco': 1, 'presented': 1, 'xoycoin': 1, 'first': 1, 'major': 1, 'upgrade': 2, 'could': 1, 'help': 2, 'turn': 1, 'staking': 2, 'business': 1, 'according': 1, 'analyst': 1, 'jpmorganrnthe': 1, 'earn': 1, 'ambition': 1, 'swelled': 1, 'even': 1, 'faster': 1, 'market': 1, 'recent': 1, 'month': 1, 'player': 1, 'mountain': 1, 'data': 1, 'try': 1, 'make': 2, 'sense': 1, 'without': 1, 'par': 1, 'shopify': 1, 'made': 1, 'possible': 1, 'eligible': 1, 'seller': 1, 'sell': 1, 'nfts': 1, 'nonfungible': 1, 'token': 1, 'via': 1, 'whole': 1, 'new': 1, 'ecommerce': 1, 'merchantsrnon': 1, 'nbas': 1, 'chicago': 1, 'bulls': 1, 'la': 1, 'finance': 1, 'insider': 1, 'writes': 1, 'strategy': 1, 'tip': 1, 'smart': 1, 'decision': 1, 'money': 1, 'receive': 1, 'small': 1, 'commission': 2, 'partner': 1, 'american': 1, 'express': 1, 'securities': 1, 'exchange': 1, 'cvm': 1, 'body': 1, 'regulates': 1, 'security': 1, 'successful': 1, 'testnet': 1, 'deployement': 1, 'london': 1, 'ready': 1, 'activated': 1, 'mainnet': 1, 'go': 1, 'live': 1, 'block': 1, 'expected': 1, 'august': 1, 'rnclie': 1, 'staffrnfile': 1, 'photo': 1, 'seen': 2, 'picture': 1, 'reutersedgar': 1, 'suillustrationfile': 1, 'photornreuters': 1, 'ro': 1, 'point': 1, 'average': 1, 'hackaday': 1, 'reader': 1, 'likely': 1, 'familiar': 1, 'proof': 1, 'pow': 1, 'dogecoin': 1, 'basic': 1, 'term': 1, 'cryptocu': 1, 'representation': 1, 'virtual': 1, 'front': 1, 'graph': 1, 'takenmay': 1, 'ruvicillustrationjuly': 1, 'dropped': 1}
#
# Here's the most commont: {'char': 20, 'ethereum': 13, 'bitcoin': 8, 'cryptocurrency': 8, 'network': 6, 'blockchain': 4, 'world': 4, 'ha': 4, 'investor': 3, 'like': 3}

# %%
# Generate the Ethereum N-grams where N=2
eth_bigrams = Counter(ngrams(eth_tokens,n=2))

print(f"Here ETH bigrams: \n"
      f"\n"
      f"{dict(eth_bigrams)}")
# Out:
# Here ETH bigrams:
#
# {('many', 'blockchain'): 1, ('blockchain', 'platform'): 1, ('platform', 'competing'): 1, ('competing', 'investor'): 1, ('investor', 'developer'): 1, ('developer', 'attention'): 1, ('attention', 'right'): 1, ('right', 'big'): 1, ('big', 'daddy'): 1, ('daddy', 'ethereum'): 1, ('ethereum', 'socalled'): 1, ('socalled', 'ethereum'): 1, ('ethereum', 'killers'): 1, ('killers', 'like'): 1, ('like', 'solana'): 1, ('solana', 'wrote'): 1, ('wrote', 'char'): 1, ('char', 'blockchain'): 1, ('blockchain', 'infrastructure'): 1, ('infrastructure', 'startup'): 1, ('startup', 'heating'): 1, ('heating', 'industry'): 1, ('industry', 'fervor'): 1, ('fervor', 'brings'): 1, ('brings', 'developer'): 1, ('developer', 'user'): 1, ('user', 'space'): 1, ('space', 'still'): 1, ('still', 'feel'): 1, ('feel', 'extremely'): 1, ('extremely', 'young'): 1, ('young', 'despite'): 1, ('despite', 'heavy'): 1, ('heavy', 'institutional'): 1, ('institutional', 'embrace'): 1, ('embrace', 'crypto'): 1, ('crypto', 'char'): 1, ('char', 'retail'): 1, ('retail', 'investor'): 1, ('investor', 'grew'): 1, ('grew', 'comfortable'): 1, ('comfortable', 'buying'): 1, ('buying', 'cryptocurrencies'): 1, ('cryptocurrencies', 'like'): 1, ('like', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 2, ('ethereum', 'decentralized'): 1, ('decentralized', 'application'): 1, ('application', 'world'): 1, ('world', 'still'): 1, ('still', 'ha'): 1, ('ha', 'lot'): 1, ('lot', 'work'): 1, ('work', 'come'): 1, ('come', 'onboarding'): 1, ('onboarding', 'char'): 1, ('char', 'cryptocurrencies'): 1, ('cryptocurrencies', 'spiked'): 1, ('spiked', 'monday'): 1, ('monday', 'amazon'): 1, ('amazon', 'listed'): 1, ('listed', 'open'): 1, ('open', 'job'): 1, ('job', 'digital'): 1, ('digital', 'currency'): 1, ('currency', 'blockchain'): 1, ('blockchain', 'product'): 1, ('product', 'leadxarnamazon'): 1, ('leadxarnamazon', 'known'): 1, ('known', 'plummeting'): 1, ('plummeting', 'stock'): 1, ('stock', 'wouldbe'): 1, ('wouldbe', 'rival'): 1, ('rival', 'whenever'): 1, ('whenever', 'rumor'): 1, ('rumor', 'swirl'): 1, ('swirl', 'char'): 1, ('char', 'bitcoin'): 1, ('bitcoin', 'ethereumrnyuriko'): 1, ('ethereumrnyuriko', 'nakaornether'): 1, ('nakaornether', 'overtook'): 1, ('overtook', 'bitcoin'): 1, ('bitcoin', 'number'): 1, ('number', 'active'): 1, ('active', 'address'): 1, ('address', 'network'): 1, ('network', 'friday'): 1, ('friday', 'sign'): 1, ('sign', 'demand'): 1, ('demand', 'faltering'): 1, ('faltering', 'world'): 1, ('world', 'biggest'): 1, ('biggest', 'cryptocurrency'): 1, ('cryptocurrency', 'co'): 1, ('co', 'char'): 1, ('char', 'anthony'): 1, ('anthony', 'di'): 1, ('di', 'iorio'): 1, ('iorio', 'cofounder'): 1, ('cofounder', 'ethereum'): 1, ('ethereum', 'network'): 4, ('network', 'say'): 1, ('say', 'done'): 1, ('done', 'cryptocurrency'): 1, ('cryptocurrency', 'world'): 1, ('world', 'partially'): 1, ('partially', 'personal'): 1, ('personal', 'safety'): 1, ('safety', 'concern'): 1, ('concern', 'report'): 1, ('report', 'bloomberg'): 1, ('bloomberg', 'story'): 1, ('story', 'shared'): 1, ('shared', 'slashdot'): 1, ('slashdot', 'char'): 1, ('char', 'representations'): 1, ('representations', 'cryptocurrency'): 1, ('cryptocurrency', 'ethereum'): 4, ('ethereum', 'placed'): 1, ('placed', 'pc'): 1, ('pc', 'motherboard'): 1, ('motherboard', 'illustration'): 1, ('illustration', 'taken'): 1, ('taken', 'june'): 2, ('june', 'reutersdado'): 1, ('reutersdado', 'ruvicillustrationnew'): 1, ('ruvicillustrationnew', 'york'): 1, ('york', 'july'): 1, ('july', 'reuters'): 1, ('reuters', 'ethereum'): 1, ('ethereum', 'secondla'): 1, ('secondla', 'char'): 1, ('char', 'ether'): 2, ('ether', 'holder'): 1, ('holder', 'staked'): 2, ('staked', 'billion'): 2, ('billion', 'worth'): 2, ('worth', 'cryptocurrency'): 2, ('network', 'excitement'): 2, ('excitement', 'build'): 1, ('build', 'around'): 1, ('around', 'overhaul'): 1, ('overhaul', 'system'): 1, ('system', 'potential'): 1, ('potential', 'growth'): 1, ('growth', 'staki'): 1, ('staki', 'char'): 1, ('eth ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_top10_token_count = token_count(btc_tokens)

print(f"Here are the top 10 words for BTC: \n"
      f" \n"
      f"{dict(btc_top10_token_count)}")
# Out:
# Here are the top 10 words for BTC:
#
# {'char': 20, 'bitcoin': 14, 'attack': 7, 'reuters': 7, 'illustration': 7, 'reutersdado': 7, 'seen': 6, 'taken': 6, 'virtual': 5, 'currency': 5}

# %%
# Use token_count to get the top 10 words for Ethereum
eth_top10_token_count = token_count(eth_tokens)

print(f"Here are the top 10 words for ETH: \n"
      f" \n"
      f"{dict(eth_top10_token_count)}")
# Out:
# Here are the top 10 words for ETH:
#
# {'char': 20, 'ethereum': 13, 'bitcoin': 8, 'cryptocurrency': 8, 'network': 6, 'blockchain': 4, 'world': 4, 'ha': 4, 'investor': 3, 'like': 3}

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
btc_token_str = ' '.join(btc_tokens)
btc_token_str
# Out:
# 'like dogecoin devotee mayor reno leader el salvador aldo baoicchi convinced cryptocurrency future ceo founder canadian scooter maker daymak belief char filed underrnthe supply chain attack ha reached thousand organizationsrnillustration alex castro vergernthree day ransomware attacker started holiday weekend comprom char image copyrightgetty imagesrnthe gang behind colossal ransomware attack ha demanded paid bitcoin return universal decryptor say unlock file char get roundup techcrunchs biggest important story delivered inbox every day pm pdt subscribe herernhello welcome daily crunch july char retail investor grew comfortable buying cryptocurrencies like bitcoin ethereum decentralized application world still ha lot work come onboarding char longtime techcrunch reader know well michael arrington cofounded techcrunch crunchbase well venture fund crunchfund wa later renamed tuesday capital arringto char singapore july reuters bitcoin broke wednesday headed another attempt breaking monthslong range short seller bailed trader drew confidence fr char reuters staffrnfile photo representations bitcoin cryptocurrency seen illustration picture taken june reutersedgar suillustrationfile photornreuters bitcoin ro char representation virtual currency bitcoin seen front stock graph illustration taken march reutersdado ruvicillustrationlondon june reuters youre bitcoi char james martincnetrna uk man wa arrested spain alleged role massive hack highprofile twitter account targeted politiciansxaand celebrity us department justi char representation virtual currency bitcoin seen front stock graph illustration takenmay reutersdado ruvicillustrationjuly reuters bitcoin dropped char representation virtual currency bitcoin seen front stock graph illustration taken november reutersdado ruvicillustrationsingapore july reuters bitcoin reco char reuters staffrnfile photo representation virtual currency bitcoin seen front stock graph illustration taken november reutersdado ruvicillustrationrnsingapore char representations cryptocurrencies bitcoin ethereum dogecoin ripple litecoin placed pc motherboard illustration taken june reutersdado ruvicillustrationwashington ju char reutersdado ruvicillustrationrnwelcome things opening bell wa forwarded sign herernmarkets insider selling first nfts get detail herernlets get char opinions expressed entrepreneur contributor ownrni launched first business three decade ago launched recent business six month ago ive invested dozen si char representations virtual currency bitcoin seen front tesla logo illustration taken february reutersdado ruvicjuly reuters electriccar maker tesla inc tslao w char ransomware attack fueled covid pandemic turbulence become major money earner cybercriminals number attack rising rnthese fileencrypting attack continu char image captionthe group recently demanded huge bitcoin ransom attack targeting firm kaseyarnwebsites russianlinked ransomware gang blamed attack hundred business world char circle ha announced plan become public company cryptocurrency company merge concord acquisition corp spac circle better known one founding member th char'

# %%
# Generate the Bitcoin word cloud
btc_token_str = ' '.join(btc_tokens)

btc_wc = WordCloud().generate(btc_token_str)

plt.imshow(btc_wc)
plt.title("Bitcoin Word Cloud", fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Bitcoin Word Cloud')

# %%
# Generate the Ethereum word cloud
eth_token_str = ' '.join(eth_tokens)

etc_wc = WordCloud().generate(eth_token_str)

plt.imshow(etc_wc)
plt.title("Ethereum Word Cloud", fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Ethereum Word Cloud')

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text
# Out:
# '[\'Like Dogecoin devotees, the mayor of Reno, and the leaders of El Salvador, Aldo Baoicchi is convinced cryptocurrency is the future. The CEO and founder of Canadian scooter maker Daymak believes this … [+4116 chars]\', \'Filed under:\\r\\nThe supply chain attack has reached over a thousand organizations.\\r\\nIllustration by Alex Castro / The Verge\\r\\nThree days after ransomware attackers started the holiday weekend by comprom… [+3376 chars]\', \'image copyrightGetty Images\\r\\nThe gang behind a "colossal" ransomware attack has demanded $70m (£50.5m) paid in Bitcoin in return for a "universal decryptor" that it says will unlock the files of all … [+4140 chars]\', \'To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox every day at 3 p.m. PDT, subscribe here.\\r\\nHello and welcome to Daily Crunch for July 23, 2021. Its been an i… [+5456 chars]\', \'While retail investors grew more comfortable buying cryptocurrencies like Bitcoin and Ethereum in 2021, the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]\', \'As longtime TechCrunch readers know well, Michael Arrington cofounded TechCrunch and Crunchbase, as well as the venture fund CrunchFund, which was later renamed Tuesday Capital. But In 2017, Arringto… [+12730 chars]\', \'SINGAPORE, July 28 (Reuters) - Bitcoin broke above $40,000 on Wednesday and headed for another attempt at breaking from its monthslong range as short sellers bailed out and traders drew confidence fr… [+351 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/Illustration/File Photo\\r\\n(Reuters) - Bitcoin ros… [+304 chars]\', "A representation of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken March 15, 2021. REUTERS/Dado Ruvic/IllustrationLONDON, June 30 (Reuters) - If you\'re a bitcoi… [+3630 chars]", \'James Martin/CNET\\r\\nA UK man was arrested in Spain for his alleged role in a massive hack of high-profile Twitter accounts that targeted politicians\\xa0and celebrities in 2020, the US Department of Justi… [+1397 chars]\', \'A representations of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken,May 19, 2021. REUTERS/Dado Ruvic/IllustrationJuly 1 (Reuters) - Bitcoin dropped 5.17% to $33… [+441 chars]\', \'A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/IllustrationSINGAPORE, July 21 (Reuters) - Bitcoin reco… [+497 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\\r\\nSINGAPORE (… [+410 chars]\', \'Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationWASHINGTON, Ju… [+3970 chars]\', "REUTERS/Dado Ruvic/Illustration\\r\\nWelcome to 10 Things Before the Opening Bell. If this was forwarded to you, sign up here.\\r\\nMarkets Insider is selling its first NFTs. Get the details here.\\r\\nLet\'s get… [+2549 chars]", \'Opinions expressed by Entrepreneur contributors are their own.\\r\\nI launched my first business more than three decades ago. I launched my most recent business six months ago. I’ve invested in dozens si… [+4277 chars]\', \'Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken, February 9, 2021. REUTERS/Dado RuvicJuly 21 (Reuters) - Electric-car maker Tesla Inc (TSLA.O) w… [+711 chars]\', \'Ransomware attacks, fueled by COVID-19 pandemic turbulence, have become a major money earner for cybercriminals, with the number of attacks rising in 2020.\\r\\nThese file-encrypting attacks have continu ...

# %%
# Run the NER processor on all of the text
btc_ner = nlp(btc_text)

# Add a title to the document
btc_ner.user_data["title"] = "BTC Named Entity Recognition (NER) document"

# %%
# Render the visualization
displacy.render(btc_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BTC Named Entity Recognition (NER) document</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">['Like Dogecoin devotees, the mayor of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reno
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and the leaders of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aldo Baoicchi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is convinced cryptocurrency is the future. The CEO and founder of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  scooter maker
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daymak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  believes this … [+4116 chars]', 'Filed under:\r\nThe supply chain attack has reached over a thousand organizations.\r\nIllustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge\r\nThree days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after ransomware attackers started
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the holiday weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by comprom… [+3376 chars]', 'image copyrightGetty Images\r\nThe gang behind a &quot;colossal&quot; ransomware attack has demanded
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $70m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     £50.5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) paid in Bitcoin in return for a &quot;universal decryptor&quot; that it says will unlock the files of all … [+4140 chars]', 'To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 p.m. PDT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , subscribe here.\r\nHello and welcome to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daily Crunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 23, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Its been an i… [+5456 chars]', 'While retail investors grew more comfortable buying cryptocurrencies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin and Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]', 'As longtime TechCrunch readers know well,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Arrington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  cofounded
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TechCrunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crunchbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , as well as the venture fund
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CrunchFund
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , which was later renamed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Capital. But In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Arringto… [+12730 chars]', 'SING

# %%
# List all Entities
print(f"These are BTC entities: \n"
      f"\n"
      f"{btc_ner.ents}")
# Out:
# These are BTC entities:
#
# (Reno, El Salvador, Aldo Baoicchi, Canadian, Daymak, Alex Castro, Verge\r\nThree days, the holiday weekend, $70m, £50.5m, every day, 3 p.m. PDT, Daily Crunch, July 23, 2021, Bitcoin and Ethereum, 2021, Michael Arrington, TechCrunch, Crunchbase, CrunchFund, Tuesday, 2017, July 28, Reuters, 40,000, Wednesday, Reuters, June 7, 2021, REUTERS, Edgar Su/Illustration/File, +304, March 15, 2021, REUTERS, Dado Ruvic/, June 30, Reuters, James Martin, UK, Spain, Twitter, 2020, the US Department of Justi, May 19, 2021, REUTERS, Dado Ruvic, Reuters, 5.17%, 33, November 19, 2020, REUTERS, Dado Ruvic/IllustrationSINGAPORE, July 21, Reuters, Reuters, November 19, 2020, REUTERS, Dado Ruvic/Illustration\r\nSINGAPORE, June 29, 2021, REUTERS, Dado Ruvic, Ju, REUTERS, Dado Ruvic, 10, the Opening Bell, first, Entrepreneur, first, more than three decades ago, six months ago, dozens, February 9, 2021, REUTERS, Dado, Reuters, Tesla Inc, 2020.\r\nThese, Russian, hundreds, Concord Acquisition Corp, SPAC)

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text
# Out:
# '[\'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]\', \'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars]\', \'While retail investors grew more comfortable buying cryptocurrencies like Bitcoin and Ethereum in 2021, the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]\', \'Cryptocurrencies spiked Monday after Amazon listed an open job for a digital currency and blockchain product lead.\\xa0\\r\\nAmazon is known for plummeting the stocks of would-be rivals whenever rumors swirl… [+1425 chars]\', "Bitcoin and Ethereum\\r\\nYuriko Nakao\\r\\nEther overtook bitcoin in the number of active addresses on its network on Friday, a sign that demand is faltering for the world\'s biggest cryptocurrency as its co… [+2727 chars]", \'"Anthony Di Iorio, a co-founder of the Ethereum network, says he\\\'s done with the cryptocurrency world, partially because of personal safety concerns," reports Bloomberg, in a story shared by Slashdot… [+1550 chars]\', \'Representations of cryptocurrency Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, July 30 (Reuters) - Ethereum, the second-la… [+3949 chars]\', \'Ether holders have "staked" more than $13 billion worth of the cryptocurrency on the ethereum 2.0 network, as excitement builds around the overhaul of the system and the potential growth of the staki… [+1851 chars]\', \'Ether is the cryptocurrency of the ethereum network.\\r\\nPhotothek/Getty Images\\r\\nEther holders have "staked" more than $13 billion worth of the cryptocurrency on the ethereum 2.0 network, as excitement … [+1935 chars]\', \'All the sessions from Transform 2021 are available on-demand now. Watch now.\\r\\nLivepeer has raised $20 million for its decentralized video transcoding network built on the Ethereum blockchain.\\xa0Its ano… [+6544 chars]\', \'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\\r\\nThe firm Xoy Capital , based in Guadalajara, Jalisco, presented Xoycoin , the first … [+3547 chars]\', \'Major upgrades to the ethereum network could help turn crypto staking into a $40 billion business by 2025, according to analysts at JPMorgan.\\r\\nThe staking industry in which users earn cryptocurrency … [+2320 chars]\', \'While the ambitions of crypto investors have swelled even faster than the market has in recent months, institutional players have had a mountain of blockchain data to try to make sense of without par… [+2313 chars]\', \'Shopify has made it possible for eligible sellers to sell NFTs (non-fungible tokens) via its platform, which opens up a whole new world for e-commerce merchants.\\r\\nOn Monday, the NBAs Chicago Bulls la… [+2148 chars]\', \'Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+5827 chars]\', \'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\\r\\nThe Securities and Exchange Commission (CVM), the body that regulates securities in … [+1015 chars]\', \'After a successful testnet deployement, the London upgrade is now ready to be activated on the Ethereum mainnet. It will go live on block 12 965 000, which is expected between August 3-5, 2021.\\r\\nClie… [+5964 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/Illustration/File Photo\\r\\n(Reuters) - Bitcoi ...

# %%
# Run the NER processor on all of the text
eth_ner = nlp(eth_text)

# Add a title to the document
eth_ner.user_data["title"] = "ETH Named Entity Recognition (NER) document"

# %%
# Render the visualization
displacy.render(eth_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETH Named Entity Recognition (NER) document</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">['There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , to so-called “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Killers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ” like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Solana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , which we wrote… [+2563 chars]', 'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars]', 'While retail investors grew more comfortable buying cryptocurrencies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin and Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]', 'Cryptocurrencies spiked
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  listed an open job for a digital currency and blockchain product lead.\xa0\r\nAmazon is known for plummeting the stocks of would-be rivals whenever rumors swirl… [+1425 chars]', &quot;Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther overtook bitcoin in the number of active addresses on its network on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a sign that demand is faltering for the world's biggest cryptocurrency as its co… [+2727 chars]&quot;, '&quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony Di Iorio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a co-founder of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  network, says he\'s done with the cryptocurrency world, partially because of personal safety concerns,&quot; reports
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , in a story shared by
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Slashdot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# … [+1550 chars]', 'Representations of cryptocurrency
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /IllustrationNEW YORK,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ethereum, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -la… [+3949 chars]', 'Ether holders have &quot;staked&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $13 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of the cryptocurrency on the ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: midd

# %%
# List all Entities
print(f"These are ETH entities: \n"
      f"\n"
      f"{eth_ner.ents}")
# Out:
# These are ETH entities:
#
# (Ethereum, Ethereum Killers, Solana, Bitcoin and Ethereum, 2021, Monday, Amazon, Friday, Anthony Di Iorio, Ethereum, Bloomberg, Slashdot, Ethereum, June 29, 2021, REUTERS, Dado Ruvic, July 30, Reuters, second, more than $13 billion, 2.0, Getty, more than $13 billion, 2.0, $20 million, Ethereum, Spanish, AI, Xoy Capital, Guadalajara, Jalisco, Xoycoin, $40 billion, 2025, recent months, Monday, Chicago Bulls, American Express, Spanish, AI, this process.\r\nThe Securities and Exchange Commission, London, Ethereum, 12 965 000, August 3-5, Reuters, June 7, 2021, REUTERS, Edgar Su/Illustration/File, +304, Hackaday, Proof of Work, Bitcoin, Ethereum, May 19, 2021, REUTERS, Dado Ruvic, Reuters, 5.17%, 33)

# %% [markdown]
# ---
