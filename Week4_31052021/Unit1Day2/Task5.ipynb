# %% [markdown]
# # Sorting Pandas DataFrames

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
data = r'C:\Users\TribThapa\Desktop\Thapa\ResearchFellow\Courses\FinTech_Bootcamp_MonashUni2021\monu-mel-virt-fin-pt-05-2021-u-c\Activities\Week 4\2\05-sorting-01\Resources\people_cleansed.csv'

# %% [markdown]
# ## 3. Read the CSV into a Pandas DataFrame

# %%
# Read in the CSV as a DataFrame
data_df = pd.read_csv(data)
data_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...

# %% [markdown]
# ## 4. Sort DataFrame in Ascending Order

# %%
data_df.sort_values(['Last_Name'], ascending=True)
# Out:
#      Person_ID Last_Name First_Name  Gender  \
# 672        691   Abramin      Alwin    Male
# 711        730  Abrehart    Gaylord    Male
# 35          37     Abson      Becka  Female
# 800        822  Ackenson   Rochella  Female
# 833        856    Acosta     Kerrie  Female
# ..         ...       ...        ...     ...
# 631        647   Yushkin     Moreen  Female
# 222        228   Zanassi      Alano    Male
# 137        140     Zaple        Ruy    Male
# 395        408      Zupo      Elane  Female
# 320        330  de Lloyd    Kennith    Male
#
#                                             University  \
# 672              University of Applied Sciences Aargau
# 711                           Université Badji Mokhtar
# 35   Ecole Nationale Supérieure d'Hydraulique et de...
# 800                     St. Luke' s College of Nursing
# 833  Institut National des Postes et Télécommunicat...
# ..                                                 ...
# ...

# %%
data_df.sort_values(['Last_Name'])
# Out:
#      Person_ID Last_Name First_Name  Gender  \
# 672        691   Abramin      Alwin    Male
# 711        730  Abrehart    Gaylord    Male
# 35          37     Abson      Becka  Female
# 800        822  Ackenson   Rochella  Female
# 833        856    Acosta     Kerrie  Female
# ..         ...       ...        ...     ...
# 631        647   Yushkin     Moreen  Female
# 222        228   Zanassi      Alano    Male
# 137        140     Zaple        Ruy    Male
# 395        408      Zupo      Elane  Female
# 320        330  de Lloyd    Kennith    Male
#
#                                             University  \
# 672              University of Applied Sciences Aargau
# 711                           Université Badji Mokhtar
# 35   Ecole Nationale Supérieure d'Hydraulique et de...
# 800                     St. Luke' s College of Nursing
# 833  Institut National des Postes et Télécommunicat...
# ..                                                 ...
# ...

# %% [markdown]
# ## 5. Sort DataFrame in Descending Order

# %%
# Sort descending
data_df.sort_values(['Last_Name'], ascending=False)
# Out:
#      Person_ID Last_Name First_Name  Gender  \
# 320        330  de Lloyd    Kennith    Male
# 395        408      Zupo      Elane  Female
# 137        140     Zaple        Ruy    Male
# 222        228   Zanassi      Alano    Male
# 631        647   Yushkin     Moreen  Female
# ..         ...       ...        ...     ...
# 833        856    Acosta     Kerrie  Female
# 800        822  Ackenson   Rochella  Female
# 35          37     Abson      Becka  Female
# 711        730  Abrehart    Gaylord    Male
# 672        691   Abramin      Alwin    Male
#
#                                             University  \
# 320                               University of Trento
# 395                          Chukyo Women's University
# 137                             Universidad de Granada
# 222                         Janus Pannonius University
# 631                                    Lourdes College
# ..                                                 ...
# ...
