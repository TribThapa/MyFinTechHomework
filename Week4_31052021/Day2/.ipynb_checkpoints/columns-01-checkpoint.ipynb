# %% [markdown]
# # Column Manipulation of Pandas DataFrames

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas, pathlib, and numpy libraries
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
data = r'C:\Users\TribThapa\Desktop\Thapa\ResearchFellow\Courses\FinTech_Bootcamp_MonashUni2021\monu-mel-virt-fin-pt-05-2021-u-c\Activities\Week 4\2\02-columns-01\Resources\people.csv'

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame and Display a Few Rows

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
data_df = pd.read_csv(data)
data_df.head(10)
# Out:
#      id  first_name    last_name                            email  gender  \
# 0   1.0     Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1   2.0     Huntley        Rupke              hrupke1@reuters.com    Male
# 2   3.0      Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3   4.0      Cullie          NaN               cputten3@nymag.com    Male
# 4   5.0       Ariel    Strangman       astrangman4@bravesites.com  Female
# 5   6.0     Antonio    Snozzwell            asnozzwell5@mysql.com    Male
# 6   7.0       Darya     Neathway            dneathway6@seesaa.net  Female
# 7   8.0     Helaina       Duding               hduding7@topsy.com  Female
# 8   9.0  Gerhardine   Franzolini             gfranzolini8@msn.com  Female
# 9  10.0       Charo        Traut               ctraut9@oracle.com  Female
#
#                                             uni_grad  \
# 0                                  Aurora University
# 1                      Osaka University of Economics
# 2                                  Ludong University
# 3  Université des Sciences et de la Technologie d...
# 4                             Boise State University
# 5                                 Babcock University
# 6                                     Molloy College
# 7                                St. Paul University
# 8                  Fundação Educacional de Ituverava
# 9                                 Cornell University
#
#                   job_title    Income
# 0        Nurse Practicioner   58135.0
# 1           Project Manager   96053.0
# 2        Environmental Tech   59196.0
# 3           Legal Assistant   88493.0
# 4           Project Manager   89073.0
# 5          Technical Writer  119916.0
# 6    Administrative Officer   77705.0
# 7           Staff Scientist   57166.0
# 8  Environmental Specialist   73051.0
# 9            Programmer III   90631.0

# %% [markdown]
# ### 4. View Column Names

# %%
# Use the `columns` attribute to output the column names
data_df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'uni_grad',
#        'job_title', 'Income'],
#       dtype='object')

# %% [markdown]
# ### 5. View Column Data Types

# %%
# Use the `dtypes` attribute to output the column names and data types
data_df.dtypes
# Out:
# id            float64
# first_name     object
# last_name      object
# email          object
# gender         object
# uni_grad       object
# job_title      object
# Income        float64
# dtype: object

# %% [markdown]
# ### 6. Rename Columns Using List

# %%
# Set the `columns` attribute to a new list of column names
col_names = ['Person_ID', 'First_Name', 'Last_Name', 'Email', 'Gender', 'University', 'Occupation', 'Salary']

data_df.columns = col_names
data_df.head(10)
# Out:
#    Person_ID  First_Name    Last_Name                            Email  \
# 0        1.0     Keriann    Lenormand  klenormand0@businessinsider.com
# 1        2.0     Huntley        Rupke              hrupke1@reuters.com
# 2        3.0      Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3        4.0      Cullie          NaN               cputten3@nymag.com
# 4        5.0       Ariel    Strangman       astrangman4@bravesites.com
# 5        6.0     Antonio    Snozzwell            asnozzwell5@mysql.com
# 6        7.0       Darya     Neathway            dneathway6@seesaa.net
# 7        8.0     Helaina       Duding               hduding7@topsy.com
# 8        9.0  Gerhardine   Franzolini             gfranzolini8@msn.com
# 9       10.0       Charo        Traut               ctraut9@oracle.com
#
#    Gender                                         University  \
# 0  Female                                  Aurora University
# 1    Male                      Osaka University of Economics
# 2    Male                                  Ludong University
# 3    Male  Université des Sciences et de la Technologie d...
# 4  Female                             Boise State University
# 5    Male                                 Babcock University
# 6  Female                                     Molloy College
# 7  Female                                St. Paul University
# 8  Female                  Fundação Educacional de Ituverava
# 9  Female                                 Cornell University
#
#                  Occupation    Salary
# 0        Nurse Practicioner   58135.0
# 1           Project Manager   96053.0
# 2        Environmental Tech   59196.0
# 3           Legal Assistant   88493.0
# 4           Project Manager   89073.0
# 5          Technical Writer  119916.0
# 6    Administrative Officer   77705.0
# 7           Staff Scientist   57166.0
# 8  Environmental Specialist   73051.0
# 9            Programmer III   90631.0

# %%
data_df.head(10)
# Out:
#    Person_ID  First_Name    Last_Name                            Email  \
# 0        1.0     Keriann    Lenormand  klenormand0@businessinsider.com
# 1        2.0     Huntley        Rupke              hrupke1@reuters.com
# 2        3.0      Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3        4.0      Cullie          NaN               cputten3@nymag.com
# 4        5.0       Ariel    Strangman       astrangman4@bravesites.com
# 5        6.0     Antonio    Snozzwell            asnozzwell5@mysql.com
# 6        7.0       Darya     Neathway            dneathway6@seesaa.net
# 7        8.0     Helaina       Duding               hduding7@topsy.com
# 8        9.0  Gerhardine   Franzolini             gfranzolini8@msn.com
# 9       10.0       Charo        Traut               ctraut9@oracle.com
#
#    Gender                                         University  \
# 0  Female                                  Aurora University
# 1    Male                      Osaka University of Economics
# 2    Male                                  Ludong University
# 3    Male  Université des Sciences et de la Technologie d...
# 4  Female                             Boise State University
# 5    Male                                 Babcock University
# 6  Female                                     Molloy College
# 7  Female                                St. Paul University
# 8  Female                  Fundação Educacional de Ituverava
# 9  Female                                 Cornell University
#
#                  Occupation    Salary
# 0        Nurse Practicioner   58135.0
# 1           Project Manager   96053.0
# 2        Environmental Tech   59196.0
# 3           Legal Assistant   88493.0
# 4           Project Manager   89073.0
# 5          Technical Writer  119916.0
# 6    Administrative Officer   77705.0
# 7           Staff Scientist   57166.0
# 8  Environmental Specialist   73051.0
# 9            Programmer III   90631.0

# %% [markdown]
# ### 7. Rename Columns Using Dictionary

# %%
# Use the `rename` function and set the `columns` parameter to a dictionary of new column names
df_new = data_df.rename(columns={'id': 'Person_ID',
                                 'first_name': 'First_Name',
                                 'last_name': 'Last_Name',
                                 'email': 'Email',
                                 'gender': 'Gender',
                                 'uni_grad': 'University',
                                 'job_title': 'Occupation',
                                 'Income': 'Salary'})
df_new.head(10)
# Out:
#    Person_ID  First_Name    Last_Name                            Email  \
# 0        1.0     Keriann    Lenormand  klenormand0@businessinsider.com
# 1        2.0     Huntley        Rupke              hrupke1@reuters.com
# 2        3.0      Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3        4.0      Cullie          NaN               cputten3@nymag.com
# 4        5.0       Ariel    Strangman       astrangman4@bravesites.com
# 5        6.0     Antonio    Snozzwell            asnozzwell5@mysql.com
# 6        7.0       Darya     Neathway            dneathway6@seesaa.net
# 7        8.0     Helaina       Duding               hduding7@topsy.com
# 8        9.0  Gerhardine   Franzolini             gfranzolini8@msn.com
# 9       10.0       Charo        Traut               ctraut9@oracle.com
#
#    Gender                                         University  \
# 0  Female                                  Aurora University
# 1    Male                      Osaka University of Economics
# 2    Male                                  Ludong University
# 3    Male  Université des Sciences et de la Technologie d...
# 4  Female                             Boise State University
# 5    Male                                 Babcock University
# 6  Female                                     Molloy College
# 7  Female                                St. Paul University
# 8  Female                  Fundação Educacional de Ituverava
# 9  Female                                 Cornell University
#
#                  Occupation    Salary
# 0        Nurse Practicioner   58135.0
# 1           Project Manager   96053.0
# 2        Environmental Tech   59196.0
# 3           Legal Assistant   88493.0
# 4           Project Manager   89073.0
# 5          Technical Writer  119916.0
# 6    Administrative Officer   77705.0
# 7           Staff Scientist   57166.0
# 8  Environmental Specialist   73051.0
# 9            Programmer III   90631.0

# %% [markdown]
# ### 8. Re-order Columns

# %%
# Use a list of re-ordered column names to alter the column order of the original DataFrame
cols = list(data_df.columns)
cols

data_df = data_df[data_df.columns[[1,2,3,5,6,7,0]]]
data_df.head()
# Out:
#   First_Name    Last_Name                            Email  \
# 0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1    Huntley        Rupke              hrupke1@reuters.com
# 2     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3     Cullie          NaN               cputten3@nymag.com
# 4      Ariel    Strangman       astrangman4@bravesites.com
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary  Person_ID
# 0  58135.0        1.0
# 1  96053.0        2.0
# 2  59196.0        3.0
# 3  88493.0        4.0
# 4  89073.0        5.0

# %% [markdown]
# ### 9. Create Additional Column

# %%
data_df.head()
# Out:
#   First_Name    Last_Name                            Email  \
# 0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1    Huntley        Rupke              hrupke1@reuters.com
# 2     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3     Cullie          NaN               cputten3@nymag.com
# 4      Ariel    Strangman       astrangman4@bravesites.com
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary  Person_ID
# 0  58135.0        1.0
# 1  96053.0        2.0
# 2  59196.0        3.0
# 3  88493.0        4.0
# 4  89073.0        5.0

# %%
# Use the `randint` function to randomly generate an `Age` from 22 to 65 for 1000 rows
import random

age = []

for i in range(len(data_df)):
               x = random.randint(22, 65)
               age.append(x)
#print(age)    
data_df['Age'] = age
data_df.head()
# Out:
#   First_Name    Last_Name                            Email  \
# 0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1    Huntley        Rupke              hrupke1@reuters.com
# 2     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3     Cullie          NaN               cputten3@nymag.com
# 4      Ariel    Strangman       astrangman4@bravesites.com
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary  Person_ID  Age
# 0  58135.0        1.0   63
# 1  96053.0        2.0   27
# 2  59196.0        3.0   22
# 3  88493.0        4.0   49
# 4  89073.0        5.0   32

# %% [markdown]
# ### 10. Delete Columns

# %%
# Use the `drop` function to delete the newly created `Age_Copy` column
data_df['Age_Copy'] = age
data_df.head()
# Out:
#   First_Name    Last_Name                            Email  \
# 0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1    Huntley        Rupke              hrupke1@reuters.com
# 2     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3     Cullie          NaN               cputten3@nymag.com
# 4      Ariel    Strangman       astrangman4@bravesites.com
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary  Person_ID  Age  Age_Copy
# 0  58135.0        1.0   63        63
# 1  96053.0        2.0   27        27
# 2  59196.0        3.0   22        22
# 3  88493.0        4.0   49        49
# 4  89073.0        5.0   32        32

# %%
data_df_new = data_df.drop('Age_Copy', 1) #axis number: 0=rows, 1=columns
data_df_new.head()
# Out:
#   First_Name    Last_Name                            Email  \
# 0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1    Huntley        Rupke              hrupke1@reuters.com
# 2     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3     Cullie          NaN               cputten3@nymag.com
# 4      Ariel    Strangman       astrangman4@bravesites.com
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary  Person_ID  Age
# 0  58135.0        1.0   63
# 1  96053.0        2.0   27
# 2  59196.0        3.0   22
# 3  88493.0        4.0   49
# 4  89073.0        5.0   32

# %% [markdown]
# ### 11. Save Modified DataFrame to New CSV

# %%
# Save the DataFrame to the `Resources` folder
OutDir = r'..\Resources\Thapa_edited.csv'

data_df_new.to_csv(OutDir, sep=',')
