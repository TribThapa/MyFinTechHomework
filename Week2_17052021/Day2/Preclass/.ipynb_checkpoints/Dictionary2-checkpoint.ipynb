# %%
Dictionary = {
    "National Bank of Canada": 327,
    "Toronto-Dominion Bank": 302,
    "Royal Bank of Canada": 173,
    "Wells Fargo": 273,
    "Goldman Sachs": 87,
    "Morgan Stanley": 72,
    "Canadian Imperial Bank of Commerce": 83,
    "TD Bank": 108,
    "Bank of Montreal": 67,
    "Capital One": 47,
    "FNB Corporation": 4,
    "Laurentian Bank of Canada": 3,
    "Ally Financial": 12,
    "Montreal Trust Company": 145,
    "Canadian Western Bank": .97
}
print(Dictionary)

# Change the market cap for 'Royal Bank of Canada'
Dictionary["National Bank of Canada"] = 500
print(Dictionary["National Bank of Canada"])
print(f"Dictionary:{Dictionary}")
print()

# Add a new bank and market cap pair
Dictionary["Commonwealth Bank of Australia"] = 450
print(f"Dictionary:{Dictionary}")
print()

# Remove a bank from the dictionary
del Dictionary["Ally Financial"]
print(Dictionary)
print()

# @TODO: Initialize metrics
total_market_cap = 0
bank_count = 0
average = 0

#Initialise minimum key-value pair
minimum_key = ""
minimum_value = 0

#Initialise maximum key-value pair
maximum_key = ""
maximum_value = 0


# Mega Cap: Firms with a market capitalization over $300 billion.
# Large Cap: Firms with a market capitalization over 10 billion. ...
# Mid Cap: A market capitalization between $2 and $10 billion.
# Small Cap: A market capitalization between $300 million and $2 billion.

mega_caps = []
large_caps = []
mid_caps = []
small_caps = []


# @TODO: Iterate over key-value pairs of the dictionary
for key, value in Dictionary.items():
    
    print(f"Name: {key} | Market cap: {value}")
    print()
                   
    # Calculate sum of market caps and number of banks in the dictionary
    total_market_cap += int(value)
    bank_count += 1

    
    # Logic to determine min value and associated key
    if minimum_value == 0:
        minimum_value = value
        minimum_key = key
    elif value < minimum_value:
        minimum_value = value
        minimum_key = key
    
    
    # Logic to determine max value and associated key
    if value > maximum_value:
        maximum_value = value
        maximum_key = key
           
       
    # Group banks by categories of market caps
    if value >= 300:
        mega_caps.append(key)
    elif value >= 10 and value < 300:
        large_caps.append(key)
    elif value >=2 and value < 10:
        mid_caps.append(key)
    elif value < 2:
        small_caps.append(key)
print()

# Calculate average market cap of banks in the dictionary
avg_market_cap = round( total_market_cap / bank_count , 2)


# Print the metrics
print(f"Total Market Capitalisation: {total_market_cap}")
print(f"Average Market Capitalisation: {avg_market_cap}")
print(f"Largest bank: {maximum_key}")
print(f"Smallest bank: {minimum_key}")
print("---------------------------------------------------")
print(f"Mega cap banks: {mega_caps}")
print(f"Large cap banks: {large_caps}")
print(f"Mid cap banks: {mid_caps}")
print(f"Small cap banks: {small_caps}")
# Out:
# {'National Bank of Canada': 327, 'Toronto-Dominion Bank': 302, 'Royal Bank of Canada': 173, 'Wells Fargo': 273, 'Goldman Sachs': 87, 'Morgan Stanley': 72, 'Canadian Imperial Bank of Commerce': 83, 'TD Bank': 108, 'Bank of Montreal': 67, 'Capital One': 47, 'FNB Corporation': 4, 'Laurentian Bank of Canada': 3, 'Ally Financial': 12, 'Montreal Trust Company': 145, 'Canadian Western Bank': 0.97}
# 500
# Dictionary:{'National Bank of Canada': 500, 'Toronto-Dominion Bank': 302, 'Royal Bank of Canada': 173, 'Wells Fargo': 273, 'Goldman Sachs': 87, 'Morgan Stanley': 72, 'Canadian Imperial Bank of Commerce': 83, 'TD Bank': 108, 'Bank of Montreal': 67, 'Capital One': 47, 'FNB Corporation': 4, 'Laurentian Bank of Canada': 3, 'Ally Financial': 12, 'Montreal Trust Company': 145, 'Canadian Western Bank': 0.97}
#
# Dictionary:{'National Bank of Canada': 500, 'Toronto-Dominion Bank': 302, 'Royal Bank of Canada': 173, 'Wells Fargo': 273, 'Goldman Sachs': 87, 'Morgan Stanley': 72, 'Canadian Imperial Bank of Commerce': 83, 'TD Bank': 108, 'Bank of Montreal': 67, 'Capital One': 47, 'FNB Corporation': 4, 'Laurentian Bank of Canada': 3, 'Ally Financial': 12, 'Montreal Trust Company': 145, 'Canadian Western Bank': 0.97, 'Commonwealth Bank of Australia': 450}
#
# {'National Bank of Canada': 500, 'Toronto-Dominion Bank': 302, 'Royal Bank of Canada': 173, 'Wells Fargo': 273, 'Goldman Sachs': 87, 'Morgan Stanley': 72, 'Canadian Imperial Bank of Commerce': 83, 'TD Bank': 108, 'Bank of Montreal': 67, 'Capital One': 47, 'FNB Corporation': 4, 'Laurentian Bank of Canada': 3, 'Montreal Trust Company': 145, 'Canadian Western Bank': 0.97, 'Commonwealth Bank of Australia': 450}
#
# Name: National Bank of Canada | Market cap: 500
#
# Name: Toronto-Dominion Bank | Market cap: 302
#
# Name: Royal Bank of Canada | Market cap: 173
#
# Name: Wells Fargo | Market cap: 273
#
# Name: Goldman Sachs | Market cap: 87
#
# Name: Morgan Stanley | Market cap: 72
#
# Name: Canadian Imperial Bank of Commerce | Market cap: 83
#
# Name: TD Bank | Market cap: 108
#
# Name: Bank of Montreal | Market cap: 67
#
# Name: Capital One | Market cap: 47
#
# Name: FNB Corporation | Market cap: 4
#
# Name: Laurentian Bank of Canada | Market cap: 3
#
# Name: Montreal Trust Company | Market cap: 145
#
# Name: Canadian Western Bank | Market cap: 0.97
#
# Name: Commonwealth Bank of Australia | Market cap: 450
#
#
# Total Market Capitalisation: 2314
# Average Market Capitalisation: 154.27
# Largest bank: National Bank of Canada
# Smallest bank: Canadian Western Bank
# ---------------------------------------------------
# Mega cap banks: ['National Bank of Canada', 'Toronto-Dominion Bank', 'Commonwealth Bank of Australia']
# Large cap banks: ['Royal Bank of Canada', 'Wells Fargo', 'Goldman Sachs', 'Morgan Stanley', 'Canadian Imperial Bank of Commerce', 'TD Bank', 'Bank of Montreal', 'Capital One', 'Montreal Trust Company']
# Mid cap banks: ['FNB Corporation', 'Laurentian Bank of Canada']
# Small cap banks: ['Canadian Western Bank']

# %%
#This script showcases the use of Python Dicts to determine the bank names associated with the corresponding market cap ranges.

# Banks and Market Caps
#-----------------------
# JP Morgan Chase: 327
# Bank of America: 302
# Citigroup: 173
# Wells Fargo: 273
# Goldman Sachs: 87
# Morgan Stanley: 72
# U.S. Bancorp: 83
# TD Bank: 108
# PNC Financial Services: 67
# Capital One: 47
# FNB Corporation: 4
# First Hawaiian Bank: 3
# Ally Financial: 12
# Wachovia: 145
# Republic Bancorp: .97

# Initialize a dictionary of banks and market caps (in billions)
banks = {
    "JP Morgan Chase": 327,
    "Bank of America": 302,
    "Citigroup": 173,
    "Wells Fargo": 273,
    "Goldman Sachs": 87,
    "Morgan Stanley": 72,
    "U.S. Bancorp": 83,
    "TD Bank": 108,
    "PNC Financial Services": 67,
    "Capital One": 47,
    "FNB Corporation": 4,
    "First Hawaiian Bank": 3,
    "Ally Financial": 12,
    "Wachovia": 145,
    "Republic Bancorp": .97
}

# Change the market cap for 'Citigroup'
banks['Citigroup'] = 170

# Add a new bank and market cap pair
banks['American Express'] = 33

# Remove a bank from the dictionary
del banks['Wachovia']

# Initialize metric variables
total_market_cap = 0
bank_count = 0
average = 0

# Initialize minimum key-value pair
minimum_key = ""
minimum_value = 0

# Initialize maximum key-value pair
maximum_key = ""
maximum_value = 0

# Mega Cap: Firms with a market capitalization greater than or equal to $300 billion.
# Large Cap: Firms with a market capitalization greater than or equal to $10 billion and less than $300 billion.
# Mid Cap: A market capitalization greater than or equal to $2 and less than $10 billion.
# Small Cap: A market capitalization greater than or equal to $300 million and less than $2 billion.

# Initialize market cap lists
mega_caps = []
large_caps = []
mid_caps = []
small_caps = []

# Iterate over key-value pairs of the dictionary
print()
for bank_name, market_cap in banks.items():
    print(f"Name: {bank_name} | Market Cap: {market_cap}")

    # Calculate sum of market caps and number of banks in the dictionary
    total_market_cap += int(market_cap)
    bank_count += 1

    # Logic to determine min value and associated key
    if minimum_value == 0:
        minimum_value = market_cap
        minimum_key = bank_name
    elif market_cap < minimum_value:
        minimum_value = market_cap
        minimum_key = bank_name

    # Logic to determine max value and associated key
    if market_cap > maximum_value:
        maximum_value = market_cap
        maximum_key = bank_name

    # Group banks by categories of market caps
    if market_cap >= 300:
        mega_caps.append(bank_name)
    elif market_cap >= 10 and market_cap < 300:
        large_caps.append(bank_name)
    elif market_cap >= 2 and market_cap < 10:
        mid_caps.append(bank_name)
    elif market_cap < 2:
        small_caps.append(bank_name)
print()

# Calculate average market cap of banks in the dictionary
avg_market_cap = round(total_market_cap / bank_count, 2)

# Print the metrics
print(f"Total Market Capitalization: {total_market_cap}")
print(f"Total Numer of Banks: {bank_count}")
print(f"Average Market Capitalization: {avg_market_cap}")
print(f"Largest Bank: {maximum_key}")
print(f"Smallest Bank: {minimum_key}")
print("------------------------------------------------")
print(f"Mega Cap Banks: {mega_caps}")
print(f"Large Cap Banks: {large_caps}")
print(f"Mid Cap Banks: {mid_caps}")
print(f"Small Cap Banks: {small_caps}")
print()
# Out:
# Name: JP Morgan Chase | Market Cap: 327
# Name: Bank of America | Market Cap: 302
# Name: Citigroup | Market Cap: 170
# Name: Wells Fargo | Market Cap: 273
# Name: Goldman Sachs | Market Cap: 87
# Name: Morgan Stanley | Market Cap: 72
# Name: U.S. Bancorp | Market Cap: 83
# Name: TD Bank | Market Cap: 108
# Name: PNC Financial Services | Market Cap: 67
# Name: Capital One | Market Cap: 47
# Name: FNB Corporation | Market Cap: 4
# Name: First Hawaiian Bank | Market Cap: 3
# Name: Ally Financial | Market Cap: 12
# Name: Republic Bancorp | Market Cap: 0.97
# Name: American Express | Market Cap: 33
#
# Total Market Capitalization: 1588
# Total Numer of Banks: 15
# Average Market Capitalization: 105.87
# Largest Bank: JP Morgan Chase
# Smallest Bank: Republic Bancorp
# ------------------------------------------------
# Mega Cap Banks: ['JP Morgan Chase', 'Bank of America']
# Large Cap Banks: ['Citigroup', 'Wells Fargo', 'Goldman Sachs', 'Morgan Stanley', 'U.S. Bancorp', 'TD Bank', 'PNC Financial Services', 'Capital One', 'Ally Financial', 'American Express']
# Mid Cap Banks: ['FNB Corporation', 'First Hawaiian Bank']
# Small Cap Banks: ['Republic Bancorp']

# %%
# Initialize a dictionary of banks and market caps (in billions)
banks = {
    "JP Morgan Chase": 327,
    "Bank of America": 302,
    "Citigroup": 173,
    "Wells Fargo": 273,
    "Goldman Sachs": 87,
    "Morgan Stanley": 72,
    "U.S. Bancorp": 83,
    "TD Bank": 108,
    "PNC Financial Services": 67,
    "Capital One": 47,
    "FNB Corporation": 4,
    "First Hawaiian Bank": 3,
    "Ally Financial": 12,
    "Wachovia": 145,
    "Republic Bancorp": .97
}

# Change the market cap for 'Citigroup'
banks['Citigroup'] = 170

# Add a new bank and market cap pair
banks['American Express'] = 33

# Remove a bank from the dictionary
del banks['Wachovia']

# Initialize metric variables
total_market_cap = 0
bank_count = 0
average = 0

# Initialize minimum key-value pair
minimum_key = ""
minimum_value = 0

# Initialize maximum key-value pair
maximum_key = ""
maximum_value = 0


# Mega Cap: Firms with a market capitalization greater than or equal to $300 billion.
# Large Cap: Firms with a market capitalization greater than or equal to $10 billion and less than $300 billion.
# Mid Cap: A market capitalization greater than or equal to $2 and less than $10 billion.
# Small Cap: A market capitalization greater than or equal to $300 million and less than $2 billion.

# Initialize market cap lists
mega_caps = []
large_caps = []
mid_caps = []
small_caps = []

# Iterate over key-value pairs of the dictionary
print()

# using the min function
min_value, min_key = min((value, key) for key, value in banks.items())
print(min_value)
print(min_key)


for bank_name, market_cap in banks.items():
    print(f"Name: {bank_name} | Market Cap: {market_cap}")

    # Calculate sum of market caps and number of banks in the dictionary
    total_market_cap += int(market_cap)
    bank_count += 1

    # Logic to determine min value and associated key
    if minimum_value == 0:
        minimum_value = market_cap
        minimum_key = bank_name
    elif market_cap < minimum_value:
        minimum_value = market_cap
        minimum_key = bank_name

    # Logic to determine max value and associated key
    if market_cap > maximum_value:
        maximum_value = market_cap
        maximum_key = bank_name

    # Group banks by categories of market caps
    if market_cap >= 300:
        mega_caps.append(bank_name)
    elif market_cap >= 10 and market_cap < 300:
        large_caps.append(bank_name)
    elif market_cap >= 2 and market_cap < 10:
        mid_caps.append(bank_name)
    elif market_cap < 2:
        small_caps.append(bank_name)
print()

# Calculate average market cap of banks in the dictionary
avg_market_cap = round(total_market_cap / bank_count, 2)

# Print the metrics
print(f"Total Market Capitalization: {total_market_cap}")
print(f"Total Numer of Banks: {bank_count}")
print(f"Average Market Capitalization: {avg_market_cap}")
print(f"Largest Bank: {maximum_key}")
print(f"Smallest Bank: {minimum_key}")
print("------------------------------------------------")
print(f"Mega Cap Banks: {mega_caps}")
print(f"Large Cap Banks: {large_caps}")
print(f"Mid Cap Banks: {mid_caps}")
print(f"Small Cap Banks: {small_caps}")
print()
# Out:
# 0.97
# Republic Bancorp
# Name: JP Morgan Chase | Market Cap: 327
# Name: Bank of America | Market Cap: 302
# Name: Citigroup | Market Cap: 170
# Name: Wells Fargo | Market Cap: 273
# Name: Goldman Sachs | Market Cap: 87
# Name: Morgan Stanley | Market Cap: 72
# Name: U.S. Bancorp | Market Cap: 83
# Name: TD Bank | Market Cap: 108
# Name: PNC Financial Services | Market Cap: 67
# Name: Capital One | Market Cap: 47
# Name: FNB Corporation | Market Cap: 4
# Name: First Hawaiian Bank | Market Cap: 3
# Name: Ally Financial | Market Cap: 12
# Name: Republic Bancorp | Market Cap: 0.97
# Name: American Express | Market Cap: 33
#
# Total Market Capitalization: 1588
# Total Numer of Banks: 15
# Average Market Capitalization: 105.87
# Largest Bank: JP Morgan Chase
# Smallest Bank: Republic Bancorp
# ------------------------------------------------
# Mega Cap Banks: ['JP Morgan Chase', 'Bank of America']
# Large Cap Banks: ['Citigroup', 'Wells Fargo', 'Goldman Sachs', 'Morgan Stanley', 'U.S. Bancorp', 'TD Bank', 'PNC Financial Services', 'Capital One', 'Ally Financial', 'American Express']
# Mid Cap Banks: ['FNB Corporation', 'First Hawaiian Bank']
# Small Cap Banks: ['Republic Bancorp']
