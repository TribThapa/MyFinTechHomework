# %% [markdown]
# # Instructor Demo: Pandas Visualizations
#
# This program reads annual gold price data from a CSV and uses line and bar charts to visualize the data.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# Set the Pandas plots to be displayed in the notebook's canvas
# %matplotlib inline

# %% [markdown]
# ### 1. Read in CSV

# %%
# Set the file path
data = Path('../Resources/annual_gold.csv')

# Read in the CSV as a DataFrame
data_df = pd.read_csv(data)
data_df.head()
# Out:
#       Date  Price
# 0  1950-12  34.72
# 1  1951-12  34.66
# 2  1952-12  34.79
# 3  1953-12  34.85
# 4  1954-12  35.04

# %% [markdown]
# ### 2. Plot Data Without Datetime Index

# %%
# Plot a line chart of the data without setting the 'Date' column as the index
data_df.plot()

# %% [markdown]
# ### 3. Set Date as Index

# %%
# Convert date strings into datetime objects and set the datetime as the index
data_df_index = data_df.set_index(pd.to_datetime(data_df['Date'], infer_datetime_format=True))
data_df_index.head()
# Out:
#                Date  Price
# Date
# 1950-12-01  1950-12  34.72
# 1951-12-01  1951-12  34.66
# 1952-12-01  1952-12  34.79
# 1953-12-01  1953-12  34.85
# 1954-12-01  1954-12  35.04

# %% [markdown]
# ### 4. Drop Extra Columns

# %%
# Drop the extra date column
data_df_index_nocol = data_df_index.drop(columns=["Date"])
data_df_index_nocol.head()
# Out:
#             Price
# Date
# 1950-12-01  34.72
# 1951-12-01  34.66
# 1952-12-01  34.79
# 1953-12-01  34.85
# 1954-12-01  35.04

# %% [markdown]
# ### 5. Plot Data with Datetime Index

# %%
# Plot a line chart of the data after converting and setting the 'Date' column as the datetime index
data_df_index_nocol.plot()

# %% [markdown]
# ### 6. Plot Bar Chart

# %%
# Plot a bar chart of the data
data_df_index_nocol.plot(kind='bar')

# %% [markdown]
# ### 7. Plot Bar Chart with Increased Figure Size

# %%
# Plot a bar chart of the data with increased figure size to see the x-axis labels
data_df_index_nocol.plot(kind='bar', figsize=(20, 10))
