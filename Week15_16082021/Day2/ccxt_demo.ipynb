# %% [markdown]
# # Going Live with CCXT

# %% [markdown]
# ### Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import ccxt
import os
import pandas as pd
from dotenv import load_dotenv

# %% [markdown]
# ### Import Environment Variables

# %%
# Load environment variables
load_dotenv()

# Import environment variables
kraken_public_key = os.getenv("KRAKEN_API_KEY")
kraken_secret_key = os.getenv("KRAKEN_SECRET_API_KEY")

# Verify that environment variables were loaded
print(f"Kraken key data type: {type(kraken_public_key)}")
print(f"Kraken secren data type: {type(kraken_secret_key)}")
# Out:
# Kraken key data type: <class 'str'>
# Kraken secren data type: <class 'str'>

# %% [markdown]
# ### Set Public and Private Keys for Kraken Exchange via the CCXT library

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({'apiKey': kraken_public_key,
                        'secret': kraken_secret_key})

# %% [markdown]
# ### Connect to Kraken and Load Available Cyptocurrency Data

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)

# Display sample data
crypto_df
# Out:
#                                                     1INCH/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 2.0, 'max': 100000000.0}, '...
# id                                                   1INCHEUR
# symbol                                              1INCH/EUR
# base                                                    1INCH
# quote                                                     EUR
# baseId                                                  1INCH
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': '1INCHEUR', 'wsname': '1INCH/EUR',...
# altname                                              1INCHEUR
# active                                                   True
#
#                                                     1INCH/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 2.0, 'max': 100000000.0}, '...
# id                                                   1INCHUSD
# symbol                                              1INCH/USD
# base                                                    1INCH
# quote                                                     USD
# baseId                                                  1INCH
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': '1INCHUSD', 'wsname': '1INCH/USD',...
# altname                                              1INCHUSD
# active                                                   True
#
#                                                      AAVE/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEAUD
# symbol                                               AAVE/AUD
# base                                                     AAVE
# quote                                                     AUD
# baseId                                                   AAVE
# quoteId                                                  ZAUD
# darkpool                                                False
# info        {'altname': 'AAVEAUD', 'wsname': 'AAVE/AUD', '...
# altname                                               AAVEAUD
# active                                                   True
#
#                                                      AAVE/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEETH
# symbol                                               AAVE/ETH
# base                                                     AAVE
# quote                                                     ETH
# baseId                                                   AAVE
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'AAVEETH', 'wsname': 'AAVE/ETH', '...
# altname                                               AAVEETH
# active                                                   True
#
#                                                      AAVE/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEEUR
# symbol                                               AAVE/EUR
# base                                                     AAVE
# quote                                                     EUR
# baseId                                                   AAVE
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'AAVEEUR', 'wsname': 'AAVE/EUR', '...
# altname                                               AAVEEUR
# active                                                   True
#
#                                                      AAVE/GBP  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEGBP
# symbol                                               AAVE/GBP
# base                                                     AAVE
# quote                                                     GBP
# baseId                                                   AAVE
# quoteId                                                  ZGBP
# darkpool                                                False
# info        {'altname': 'AAVEGBP', 'wsname': 'AAVE/GBP', '...
# altname                                               AAVEGBP
# active                                                   True
#
#                                                      AAVE/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEUSD
# symbol                                               AAVE/USD
# base                                                     AAVE
# quote                                                     USD
# baseId                                                   AAVE
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'AAVEUSD', 'wsname': 'AAVE/USD', '...
# altname                                               AAVEUSD
# active                                                   True
#
#                                                      AAVE/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEXBT
# symbol                                               AAVE/BTC
# base                                                     AAVE
# quote                                                     BTC
# baseId                                                   AAVE
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'AAVEXBT', 'wsname': 'AAVE/XBT', '...
# altname                                               AAVEXBT
# active                                                   True
#
#                                                       ADA/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ADAAUD
# symbol                                                ADA/AUD
# base                                                      ADA
# quote                                                     AUD
# baseId                                                    ADA
# quoteId                                                  ZAUD
# darkpool                                                False
# info        {'altname': 'ADAAUD', 'wsname': 'ADA/AUD', 'ac...
# altname                                                ADAAUD
# active                                                   True
#
#                                                       ADA/ETH  ...  \
# percentage                                               True  ...
# tierBased                                                True  ...
# taker                                                  0.0026  ...
# maker                                                  0.0016  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
# precision                           {'amount': 8, 'price': 7}  ...
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...  ...
# id                                                     ADAETH  ...
# symbol                                                ADA/ETH  ...
# base                                                      ADA  ...
# quote                                                     ETH  ...
# baseId                                                    ADA  ...
# quoteId                                                  XETH  ...
# darkpool                                                False  ...
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...  ...
# altname                                                ADAETH  ...
# active                                                   True  ...
#
#                                                       YFI/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 0}
# limits      {'amount': {'min': 0.00015, 'max': 100000000.0...
# id                                                     YFIUSD
# symbol                                                YFI/USD
# base                                                      YFI
# quote                                                     USD
# baseId                                                    YFI
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'YFIUSD', 'wsname': 'YFI/USD', 'ac...
# altname                                                YFIUSD
# active                                                   True
#
#                                                       YFI/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 0.00015, 'max': 100000000.0...
# id                                                     YFIXBT
# symbol                                                YFI/BTC
# base                                                      YFI
# quote                                                     BTC
# baseId                                                    YFI
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'YFIXBT', 'wsname': 'YFI/XBT', 'ac...
# altname                                                YFIXBT
# active                                                   True
#
#                                                       EUR/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                   ZEURZUSD
# symbol                                                EUR/USD
# base                                                      EUR
# quote                                                     USD
# baseId                                                   ZEUR
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# altname                                                EURUSD
# active                                                   True
#
#                                                       GBP/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                   ZGBPZUSD
# symbol                                                GBP/USD
# base                                                      GBP
# quote                                                     USD
# baseId                                                   ZGBP
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# altname                                                GBPUSD
# active                                                   True
#
#                                                       ZRX/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXEUR
# symbol                                                ZRX/EUR
# base                                                      ZRX
# quote                                                     EUR
# baseId                                                    ZRX
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ZRXEUR', 'wsname': 'ZRX/EUR', 'ac...
# altname                                                ZRXEUR
# active                                                   True
#
#                                                       ZRX/GBP  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXGBP
# symbol                                                ZRX/GBP
# base                                                      ZRX
# quote                                                     GBP
# baseId                                                    ZRX
# quoteId                                                  ZGBP
# darkpool                                                False
# info        {'altname': 'ZRXGBP', 'wsname': 'ZRX/GBP', 'ac...
# altname                                                ZRXGBP
# active                                                   True
#
#                                                       ZRX/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXUSD
# symbol                                                ZRX/USD
# base                                                      ZRX
# quote                                                     USD
# baseId                                                    ZRX
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ZRXUSD', 'wsname': 'ZRX/USD', 'ac...
# altname                                                ZRXUSD
# active                                                   True
#
#                                                       ZRX/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXXBT
# symbol                                                ZRX/BTC
# base                                                      ZRX
# quote                                                     BTC
# baseId                                                    ZRX
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ZRXXBT', 'wsname': 'ZRX/XBT', 'ac...
# altname                                                ZRXXBT
# active                                                   True
#
#                                                       USD/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZUSDZCAD
# symbol                                                USD/CAD
# base                                                      USD
# quote                                                     CAD
# baseId                                                   ZUSD
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# altname                                                USDCAD
# active                                                   True
#
#                                                       USD/JPY
# percentage                                               True
# tierBased                                                True
# taker                                                     0.0
# maker                                                     0.0
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZUSDZJPY
# symbol                                                USD/JPY
# base                                                      USD
# quote                                                     JPY
# baseId                                                   ZUSD
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# altname                                                USDJPY
# active                                                   True
#
# [17 rows x 392 columns]

# %% [markdown]
# ### List Available Cryptocurrencies for Trading

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['1INCH/EUR' '1INCH/USD' 'AAVE/AUD' 'AAVE/ETH' 'AAVE/EUR' 'AAVE/GBP'
#  'AAVE/USD' 'AAVE/BTC' 'ADA/AUD' 'ADA/ETH' 'ADA/EUR' 'ADA/GBP' 'ADA/USD'
#  'ADA/USDT' 'ADA/BTC' 'ALGO/ETH' 'ALGO/EUR' 'ALGO/GBP' 'ALGO/USD'
#  'ALGO/BTC' 'ANKR/EUR' 'ANKR/GBP' 'ANKR/USD' 'ANKR/BTC' 'ANT/ETH'
#  'ANT/EUR' 'ANT/USD' 'ANT/BTC' 'ATOM/AUD' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/GBP'
#  'ATOM/USD' 'ATOM/BTC' 'AUD/JPY' 'AUD/USD' 'AXS/EUR' 'AXS/USD'
#  'BADGER/EUR' 'BADGER/USD' 'BAL/ETH' 'BAL/EUR' 'BAL/USD' 'BAL/BTC'
#  'BAND/EUR' 'BAND/USD' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD'
#  'BCH/ETH' 'BCH/EUR' 'BCH/GBP' 'BCH/JPY' 'BCH/USD' 'BCH/USDT' 'BCH/BTC'
#  'BNT/EUR' 'BNT/GBP' 'BNT/USD' 'BNT/BTC' 'CHZ/EUR' 'CHZ/USD' 'COMP/ETH'
#  'COMP/EUR' 'COMP/USD' 'COMP/BTC' 'CQT/EUR' 'CQT/USD' 'CRV/ETH' 'CRV/EUR'
#  'CRV/USD' 'CRV/BTC' 'CTSI/EUR' 'CTSI/USD' 'DAI/EUR' 'DAI/USD' 'DAI/USDT'
#  'DASH/EUR' 'DASH/USD' 'DASH/BTC' 'DOT/AUD' 'DOT/ETH' 'DOT/EUR' 'DOT/GBP'
#  'DOT/USD' 'DOT/USDT' 'DOT/BTC' 'ENJ/EUR' 'ENJ/GBP' 'ENJ/USD' 'ENJ/BTC'
#  'EOS/ETH' 'EOS/EUR' 'EOS/USD' 'EOS/USDT' 'EOS/BTC' 'ETH2.S/ETH' 'ETH/AUD'
#  'ETH/CHF' 'ETH/DAI' 'ETH/USDC' 'ETH/USDT' 'EUR/AUD' 'EUR/CAD' 'EUR/CHF'
#  'EUR/GBP' 'EUR/JPY' 'EWT/EUR' 'EWT/GBP' 'EWT/USD' 'EWT/BTC' 'FIL/AUD'
#  'FIL/ETH' 'FIL/EUR' 'FIL/GBP' 'FIL/USD' 'FIL/BTC' 'FLOW/ETH' 'FLOW/EUR'
#  'FLOW/GBP' 'FLOW/USD' 'FLOW/BTC' 'GHST/EUR' 'GHST/GBP' 'GHST/USD'
#  'GHST/BTC' 'GNO/ETH' 'GNO/EUR' 'GNO/USD' 'GNO/BTC' 'GRT/AUD' 'GRT/ETH'
#  'GRT/EUR' 'GRT/GBP' 'GRT/USD' 'GRT/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD'
#  'ICX/BTC' 'INJ/EUR' 'INJ/USD' 'KAR/EUR' 'KAR/USD' 'KAVA/ETH' 'KAVA/EUR'
#  'KAVA/USD' 'KAVA/BTC' 'KEEP/ETH' 'KEEP/EUR' 'KEEP/USD' 'KEEP/BTC'
#  'KNC/ETH' 'KNC/EUR' 'KNC/USD' 'KNC/BTC' 'KSM/AUD' 'KSM/DOT' 'KSM/ETH'
#  'KSM/EUR' 'KSM/GBP' 'KSM/USD' 'KSM/BTC' 'LINK/AUD' 'LINK/ETH' 'LINK/EUR'
#  'LINK/GBP' 'LINK/USD' 'LINK/USDT' 'LINK/BTC' 'LPT/EUR' 'LPT/GBP'
#  'LPT/USD' 'LPT/BTC' 'LRC/EUR' 'LRC/USD' 'LSK/ETH' 'LSK/EUR' 'LSK/USD'
#  'LSK/BTC' 'LTC/AUD' 'LTC/ETH' 'LTC/GBP' 'LTC/USDT' 'MANA/ETH' 'MANA/EUR'
#  'MANA/USD' 'MANA/BTC' 'MATIC/EUR' 'MATIC/GBP' 'MATIC/USD' 'MATIC/BTC'
#  'MINA/EUR' 'MINA/GBP' 'MINA/USD' 'MINA/BTC' 'MIR/EUR' 'MIR/USD' 'MKR/EUR'
#  'MKR/GBP' 'MKR/USD' 'MKR/BTC' 'NANO/ETH' 'NANO/EUR' 'NANO/USD' 'NANO/BTC'
#  'OCEAN/EUR' 'OCEAN/GBP' 'OCEAN/USD' 'OCEAN/BTC' 'OGN/EUR' 'OGN/USD'
#  'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC' 'OXT/ETH' 'OXT/EUR' 'OXT/USD'
#  'OXT/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD' 'PAXG/BTC' 'PERP/EUR'
#  'PERP/USD' 'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'RARI/EUR'
#  'RARI/GBP' 'RARI/USD' 'RARI/BTC' 'REN/EUR' 'REN/GBP' 'REN/USD' 'REN/BTC'
#  'REP/ETH' 'REP/EUR' 'REP/USD' 'REP/BTC' 'SAND/EUR' 'SAND/GBP' 'SAND/USD'
#  'SAND/BTC' 'SC/ETH' 'SC/EUR' 'SC/USD' 'SC/BTC' 'SNX/AUD' 'SNX/ETH'
#  'SNX/EUR' 'SNX/GBP' 'SNX/USD' 'SNX/BTC' 'SOL/EUR' 'SOL/GBP' 'SOL/USD'
#  'SOL/BTC' 'SRM/EUR' 'SRM/GBP' 'SRM/USD' 'SRM/BTC' 'STORJ/ETH' 'STORJ/EUR'
#  'STORJ/USD' 'STORJ/BTC' 'SUSHI/EUR' 'SUSHI/GBP' 'SUSHI/USD' 'SUSHI/BTC'
#  'TBTC/ETH' 'TBTC/EUR' 'TBTC/USD' 'TBTC/BTC' 'TRX/ETH' 'TRX/EUR' 'TRX/USD'
#  'TRX/BTC' 'UNI/ETH' 'UNI/EUR' 'UNI/USD' 'UNI/BTC' 'USDC/AUD' 'USDC/EUR'
#  'USDC/GBP' 'USD/CHF' 'USDC/USD' 'USDC/USDT' 'USDT/AUD' 'USDT/CAD'
#  'USDT/CHF' 'USDT/EUR' 'USDT/GBP' 'USDT/JPY' 'USDT/USD' 'WAVES/ETH'
#  'WAVES/EUR' 'WAVES/USD' 'WAVES/BTC' 'WBTC/EUR' 'WBTC/USD' 'BTC/AUD'
#  'BTC/CHF' 'BTC/DAI' 'BTC/USDC' 'BTC/USDT' 'DOGE/EUR' 'DOGE/USD'
#  'DOGE/USDT' 'ETC/ETH' 'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC' 'ETHXBT.d'
#  'ETH/CAD' 'ETHCAD.d' 'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d' 'ETH/JPY'
#  'ETHJPY.d' 'ETH/USD' 'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/JPY' 'LTC/USD'
#  'MLN/ETH' 'MLN/BTC' 'MLN/EUR' 'MLN/USD' 'REPV1/ETH' 'REPV1/BTC'
#  'REPV1/EUR' 'REPV1/USD' 'XRP/AUD' 'XRP/ETH' 'XRP/GBP' 'XRP/USDT'
#  'XTZ/AUD' 'XTZ/ETH' 'XTZ/EUR' 'XTZ/GBP' 'XTZ/USD' 'XTZ/BTC' 'BTC/CAD'
#  'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d' 'BTC/GBP' 'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d'
#  'BTC/USD' 'XBTUSD.d' 'DOGE/BTC' 'XLM/BTC' 'XLM/AUD' 'XLM/EUR' 'XLM/GBP'
#  'XLM/USD' 'XMR/BTC' 'XMR/EUR' 'XMR/USD' 'XRP/BTC' 'XRP/CAD' 'XRP/EUR'
#  'XRP/JPY' 'XRP/USD' 'ZEC/BTC' 'ZEC/EUR' 'ZEC/USD' 'YFI/AUD' 'YFI/ETH'
#  'YFI/EUR' 'YFI/GBP' 'YFI/USD' 'YFI/BTC' 'EUR/USD' 'GBP/USD' 'ZRX/EUR'
#  'ZRX/GBP' 'ZRX/USD' 'ZRX/BTC' 'USD/CAD' 'USD/JPY']
# 392

# %%
# Show list of available functions for the current exchange (in this case Kraken)
exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'signIn': False,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %% [markdown]
# ### Fetch Historical Data for BTC/USD

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("BTC/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

historical_prices_df
# Out:
#          timestamp     open     high      low    close       volume
# 0    1567209600000   9577.9   9690.0   9400.0   9604.3  1980.087071
# 1    1567296000000   9602.1   9850.0   9540.8   9764.9  2143.792864
# 2    1567382400000   9765.0  10490.0   9752.8  10389.5  6360.479321
# 3    1567468800000  10389.6  10785.6  10271.6  10614.6  7101.505818
# 4    1567555200000  10619.7  10892.1  10319.0  10584.9  6149.093773
# ..             ...      ...      ...      ...      ...          ...
# 715  1628985600000  47111.8  47385.0  45550.0  47019.3  2101.359096
# 716  1629072000000  47023.7  48072.6  45697.4  45926.3  2739.390572
# 717  1629158400000  45926.2  47172.3  44401.2  44672.2  3292.642367
# 718  1629244800000  44672.3  46000.0  44250.0  44714.7  3213.179452
# 719  1629331200000  44720.2  45185.0  44000.0  44823.4   717.428144
#
# [720 rows x 6 columns]

# %% [markdown]
# ### Convert Epoch Timestamp to Readable Date Format

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime( historical_prices_df["timestamp"], unit="ms")

historical_prices_df.head()
# Out:
#        timestamp     open     high      low    close       volume       date
# 0  1567209600000   9577.9   9690.0   9400.0   9604.3  1980.087071 2019-08-31
# 1  1567296000000   9602.1   9850.0   9540.8   9764.9  2143.792864 2019-09-01
# 2  1567382400000   9765.0  10490.0   9752.8  10389.5  6360.479321 2019-09-02
# 3  1567468800000  10389.6  10785.6  10271.6  10614.6  7101.505818 2019-09-03
# 4  1567555200000  10619.7  10892.1  10319.0  10584.9  6149.093773 2019-09-04

# %% [markdown]
# ### Fetch Latest Data for BTC/USD

# %%
# Fetch current price details for `BTC/USD`
current_price = exchange.fetch_ticker('BTC/USD')

# Delete `info` key-value pair
del current_price['info']

current_price
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1629366876756,
#  'datetime': '2021-08-19T09:54:36.756Z',
#  'high': 46000.0,
#  'low': 44000.0,
#  'bid': 44826.9,
#  'bidVolume': None,
#  'ask': 44833.7,
#  'askVolume': None,
#  'vwap': 45110.87352,
#  'open': 44720.2,
#  'close': 44828.3,
#  'last': 44828.3,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 3092.78030596,
#  'quoteVolume': 139518021.20730847}

# %%
# Import data as a Pandas DataFrame
current_price_df = pd.DataFrame(current_price, index=[0])

current_price_df
# Out:
#     symbol      timestamp                  datetime     high      low  \
# 0  BTC/USD  1629366876756  2021-08-19T09:54:36.756Z  46000.0  44000.0
#
#        bid bidVolume      ask askVolume         vwap     open    close  \
# 0  44826.9      None  44833.7      None  45110.87352  44720.2  44828.3
#
#       last previousClose change percentage average   baseVolume   quoteVolume
# 0  44828.3          None   None       None    None  3092.780306  1.395180e+08

# %%
# Fetch balance
exchange.fetchBalance()
# Out:
# {'info': {'error': []},
#  'timestamp': None,
#  'datetime': None,
#  'free': {},
#  'used': {},
#  'total': {}}

# %%
# Fetch status
exchange.fetchStatus()
# Out:
# {'status': 'ok', 'updated': 1629367108000, 'eta': None, 'url': None}

# %%
# Fetch open orders
exchange.fetchOpenOrders()
# Out:
# []
