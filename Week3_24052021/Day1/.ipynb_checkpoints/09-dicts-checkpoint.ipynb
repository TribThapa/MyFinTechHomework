# %%
from show_data import shows

# %%
#print(shows)

# QUESTION 1: Who is the actor that plays Squidward in Spongebob (kids)?
print(f"The actor that plays Squidward is {shows['genre']['kids']['Spongebob']['cast'][0]['actor']}")
      
# QUESTION 2: Patrick Warburton plays Joe Swanson in Family Guy (comedy). What is the link to his imdb page?
print(f"Patrick Warburton plays Joe Swanson in Family Guy (comedy). The link to his imdb page is {shows['genre']['comedy']['family_guy']['cast'][4]['imdb']}")
      
# QUESTION 3: Is the Walking Dead still running?
print(f"Is the walking dead still running? Ans: {shows['genre']['drama']['the_walking_dead']['still_running']}")
      
# QUESTION 4: Who plays Dexter in Dexter (drama) and who plays Dexter in Dexter's Lab (kids)?
# HINT: You can print multiple items at once by using a comma like this: print(thing1, thing2)
print(f"{shows['genre']['drama']['dexter']['cast'][0]['actor']} plays Dexter in Dexter (drama), and {shows['genre']['kids']['dexters_lab']['cast'][0]['actor']} plays Dexter in Dexter's Lab (kids)")
      
# QUESTION 5: Who are the creators of Stranger Things (drama)?
print(f"The creators of Stranger Things are {shows['genre']['drama']['stranger_things']['creators'][0]}, and {shows['genre']['drama']['stranger_things']['creators'][1]}.")
      
# QUESTION 6: Who hosts the Daily Show (talk)?
print(f"{shows['genre']['talk']['the_daily_show']['host']} hosts the Daily Show")
      
# QUESTION 7: Who are all the hosts of the view (talk)
# Hint: You will need to use a loop for this one. You may not simply log the entire list, but must log each name individually
a = shows['genre']['talk']
#print(a)
for key, value in a.items():
      print(f"The host/s for {key} is/are {a[key]['host']}")
            
# QUESTION 8: What are the show names of the Impractical Jokers (comedy). Hint: You will need to use a loop for this one. You may not simply log the entire list, but must log each name individually
b = shows['genre']['comedy']['impractical_jokers']['cast']
#print(b)
length = len(b)
#print(length)
            
for i in range(length):
            print(f"The show names for Impractical Jokers (comedy) are {b[i]['showName']}")
                  
# QUESTION 9: Who does Will Arnett play in Arrested Development (comedy)
print(f"Will Arnett plays {shows['genre']['comedy']['arrested_development']['cast'][2]['character']} in Arrested Development (comedy).")
      
# QUESTION 10: Who plays Yami Yugi in Yu-Gi-Oh (kids)?
print(f"{shows['genre']['kids']['yu_gi_oh']['cast'][0]['actor']} plays Yami Yugi in Yu-Gi-Oh (kids).")
      
# QUESTION 11: How many seasons did the Office (comedy) run?
print(f"The Office ran for {shows['genre']['comedy']['the_office']['num_seasons']} seasons.")

# QUESTION 12: Who are the main characters of the Office (comedy) (not the actors, but the actual character names)?
c = shows['genre']['comedy']['the_office']['cast']
#print(c)
l = len(c)
#print(l)
for s in range(l):
      print(f"The main characters of The Office (comedy) are {c[s]['character']}.")
            
# QUESTION 13: List the characters in Teen Titans (kids)
d = shows['genre']['kids']['teen_titans']['cast']

teen_titan_length = len(d)

for teen_titan_char in range(teen_titan_length):
            print(f"The characters in Teen Titains (kids) are {d[teen_titan_char]['character']}.")
                  
# QUESTION 14: What is the link to the IMDB page for the actor who plays Mr. Krabs (Spongebob, kids)?
print(f"The link to the IMDB page for the actor who plays Mr. Krabs (Spongebob, kids) is {shows['genre']['kids']['Spongebob']['cast'][1]['imdb']}")

# QUESTION 15: Who plays Negan in The Walking Dead?
print(f"{shows['genre']['drama']['the_walking_dead']['cast'][2]['actor']} plays Negan in The Walking Dead.")

# QUESTION 16: List the main cast of Dexter (drama) (the actors, not the characters)
Dexter_dict = shows['genre']['drama']['dexter']['cast']
Dexter_dict_length = len(Dexter_dict)

for DDL in range(Dexter_dict_length):
      print(f"The main cast of Dexter (drama) are {Dexter_dict[DDL]['actor']}")

# QUESTION 17: Is Game of Thrones(drama) still running?
print(f"Is Game of Thrones still running: Is {shows['genre']['drama']['game_of_thrones']['still_running']}")
      
# QUESTION 18: Who does Peter Dinklage play in Game of Thrones (drama)?
actor_name = shows['genre']['drama']['game_of_thrones']['cast'][1]['actor']
char_name = shows['genre']['drama']['game_of_thrones']['cast'][1]['character']

if actor_name == 'Peter Dinklage':
      print(f"{actor_name} plays {char_name}.")
      
# QUESTION 19: List the American Idol Judges
American_idol_length = len(shows['genre']['reality']['american_idol']['judges'])
print(American_idol_length)

for AIL in range(American_idol_length):
      print(f"Judges for American Idol are {shows['genre']['reality']['american_idol']['judges'][AIL]}")
            
# QUESTION 20: Who plays Dustin in Stanger Things (drama)?
print(f"{shows['genre']['drama']['stranger_things']['cast'][3]['actor']} plays Dustin in Stranger Things (drama).")
# Out:
# The actor that plays Squidward is Tom Kenny
# Patrick Warburton plays Joe Swanson in Family Guy (comedy). The link to his imdb page is https://www.imdb.com/name/nm0911320/?ref_=nv_sr_2
# Is the walking dead still running? Ans: True
# Michael C. Hall plays Dexter in Dexter (drama), and Christine Cavanaugh plays Dexter in Dexter's Lab (kids)
# The creators of Stranger Things are Ross Duffer, and Matt Duffer.
# Trevor Noah hosts the Daily Show
# The host/s for real_time_with_bill_maher is/are Bill Maher
# The host/s for the_view is/are ['Whoopi Goldberg', 'Barbara Walters', 'Joy Behar', 'Star Jones', 'Meredith Vieira']
# The host/s for the_daily_show is/are Trevor Noah
# The host/s for conan is/are Conan O'Brien
# The host/s for late_night_with_seth_meyers is/are Seth Meyers
# The show names for Impractical Jokers (comedy) are Murr
# The show names for Impractical Jokers (comedy) are Joe
# The show names for Impractical Jokers (comedy) are Sal
# ...
