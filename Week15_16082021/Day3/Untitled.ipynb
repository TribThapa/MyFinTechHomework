# %%
import os
from pathlib import Path
import alpaca_trade_api as tradeapi
import pandas as pd
import numpy as np
import datetime
import time
from dotenv import load_dotenv

import requests
import json

# %%
alpha_api_key = "QBL0F29JUTZIH8ZO"

# %%
print(json.dumps(response_data, indent=4, sort_keys=True))

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
stock_symbol = ["AAPL"]

close = {}

for stock in stock_symbol:
    
    url = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={stock}&interval=60min&apikey=QBL0F29JUTZIH8ZO"
    
    r = requests.get(url)
    
    data = r.json()    
    
    #print(json.dumps(data, indent=4, sort_keys=True))

# %%
import csv
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AAPL&apikey=QBL0F29JUTZIH8ZO'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Daily Prices (open
#         "2. Symbol": "AAPL"
#         "3. Last Refreshed": "2021-08-20"
#         "4. Output Size": "Compact"
#         "5. Time Zone": "US/Eastern"
#     }
#     "Time Series (Daily)": {
#         "2021-08-20": {
#             "1. open": "147.4400"
#             "2. high": "148.5000"
#             "3. low": "146.7800"
#             "4. close": "148.1900"
#             "5. volume": "60549630"
#         }
#         "2021-08-19": {
#             "1. open": "145.0300"
#             "2. high": "148.0000"
#             "3. low": "144.5000"
#             "4. close": "146.7000"
#             "5. volume": "86960310"
#         }
#         "2021-08-18": {
#             "1. open": "149.8000"
#             "2. high": "150.7200"
#             "3. low": "146.1500"
#             "4. close": "146.3600"
#             "5. volume": "86325990"
#         }
#         "2021-08-17": {
#             "1. open": "150.2300"
# ...

# %%
for row in my_list:
    print(row[0][15:])
# Out:
# : {
# ormation": "Daily Prices (open
# bol": "AAPL"
# t Refreshed": "2021-08-20"
# put Size": "Compact"
# e Zone": "US/Eastern"
#
# s (Daily)": {
# 8-20": {
#  open": "147.4400"
#  high": "148.5000"
#  low": "146.7800"
#  close": "148.1900"
#  volume": "60549630"
#
# 8-19": {
#  open": "145.0300"
#  high": "148.0000"
#  low": "144.5000"
#  close": "146.7000"
#  volume": "86960310"
#
# 8-18": {
#  open": "149.8000"
#  high": "150.7200"
#  low": "146.1500"
#  close": "146.3600"
#  volume": "86325990"
#
# 8-17": {
#  open": "150.2300"
#  high": "151.6800"
#  low": "149.0900"
#  close": "150.1900"
#  volume": "92229735"
#
# 8-16": {
#  open": "148.5350"
#  high": "151.1900"
#  low": "146.4700"
#  close": "151.1200"
#  volume": "103558782"
#
# 8-13": {
#  open": "148.9700"
#  high": "149.4444"
#  low": "148.2700"
#  close": "149.1000"
#  volume": "58846293"
#
# 8-12": {
#  open": "146.1900"
#  high": "149.0500"
#  low": "145.8400"
#  close": "148.8900"
#  volume": "73779113"
#
# 8-11": {
# ...
