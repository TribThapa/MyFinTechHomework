# %% [markdown]
# # Instructor Do: Create and Deploy a Machine Learning Model in Amazon SageMaker

# %%
# Initial imports
import os
import io
import json
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Amazon SageMaker and related imports
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3  # AWS Python sdk

# %matplotlib inline

# %% [markdown]
# ## Reading Data

# %%
# Read the weather features data
features = pd.read_csv(('x_austin_final.csv'))
                       
# Transforming the "TempAvgF" column to a vector
X = features["TempAvgF"].values.reshape(-1, 1)

#X = np.delete(X, 0)
print(f"Shape is: {X.shape}")
# Out:
# Shape is: (1319, 1)

# %%
# Read the target data (precipitation sum inches)
y = pd.read_csv(('y_austin_final.csv'),
                 names=["PrecipitationSumInches"],
                 header=None)

# Transforming y into a vector
y = y.iloc[:, 0].values

print(f"Shape is: {y.shape}")
# Out:
# Shape is: (1319,)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,                                                 
                                                    y, 
                                                    test_size=0.2)

# %% [markdown]
# ## Creating the Linear Regression Model
#
# ### Initial Configurations

# %%
# Define Amazon S3 Bucket to store model data
bucket = "fintechweek13day2"

# Define prefix for data files
prefix = "austin-rainfall-regression"

# AWS IAM role
#role = "arn:aws:iam::009193407027:role/service-role/AmazonSageMaker-ExecutionRole-20210803T084086"
#role = ('AmazonSageMaker-ExecutionRole-20210803T074972')        

#role = 'AmazonSageMaker-ExecutionRole-20210803T084086'
role = get_execution_role()
#role = 'get_execution_role'

# %% [markdown]
# ### Uploading Training Data to Amazon S3

# %%
# Encode the training data as Protocol Buffer
buf = io.BytesIO()

vectors = np.array(X_train).astype("float32")

labels = np.array(y_train).astype("float32")

smac.write_numpy_to_dense_tensor(buf, 
                                 vectors, 
                                 labels)

buf.seek(0)

# Upload encoded training data to Amazon S3
key = "linear_train.data"

boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "train", key)).upload_fileobj(buf)


s3_train_data = "s3://{}/{}/train/{}".format(bucket, prefix, key) #f"s3://{bucket}/{prefix}/train/{key}"

print(f"Training data uploaded to: {s3_train_data}")
# Out:
# Training data uploaded to: s3://fintechweek13day2/austin-rainfall-regression/train/linear_train.data

# %% [markdown]
# ### Upload Test Data to Amazon S3

# %%
# Encode the testing data as Protocol Buffer
buf = io.BytesIO()

vectors = np.array(X_test).astype("float32")

labels = np.array(y_test).astype("float32")

smac.write_numpy_to_dense_tensor(buf, 
                                 vectors,
                                 labels)

buf.seek(0)

# Upload encoded testing data to Amazon S3
key = "linear_test.data"

boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "test", key)).upload_fileobj(buf)

s3_test_data = "s3://{}/{}/test/{}".format(bucket, prefix, key) #f"s3://{bucket}/{prefix}/test/{key}"

print(f"Testing data uploaded to: {s3_test_data}")
# Out:
# Testing data uploaded to: s3://fintechweek13day2/austin-rainfall-regression/test/linear_test.data

# %% [markdown]
# ### Creating Model Instance

# %%
# Create an instance of the linear learner algorithm
container = get_image_uri(boto3.Session().region_name,
                          "linear-learner")
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %%
# Start the Amazon SageMaker session
sess = sagemaker.Session()

# Create an instance of the linear learner estimator
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1,
                                       train_instance_type="ml.m4.xlarge",
                                       output_path=f"s3://{bucket}/{prefix}/output",
                                       sagemaker_session=sess)

# Define linear learner hyperparameters
linear.set_hyperparameters(feature_dim=1,
                           mini_batch_size=100,
                           predictor_type="regressor",
                           epochs=10,
                           num_models=32,
                           loss="absolute_loss")
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Training the Machine Learning Model

# %%
# Fitting the linear-learner model with the training data
linear.fit({"train": s3_train_data,
            "test": s3_test_data})

#s3://fintechweek13day2/arn:aws:\test\linear_test.data
# Out:
# 2021-08-04 08:41:11 Starting - Starting the training job...
# 2021-08-04 08:41:13 Starting - Launching requested ML instancesProfilerReport-1628066471: InProgress
# ......
# 2021-08-04 08:42:38 Starting - Preparing the instances for training.........
# 2021-08-04 08:43:59 Downloading - Downloading input data...
# 2021-08-04 08:44:39 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/04/2021 08:44:40 INFO 140208290785088] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [08/04/2021 08:44:40 INFO 140208290785088] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'loss': 'absolute_loss', 'feature_dim': '1', 'num_models': '32', 'predictor_type': 'regressor', 'epochs': '10', 'mini_batch_size': '100'}
# [08/04/2021 08:44:40 INFO 140208290785088] Final configuration: {'mini_batch_size': '100', 'epochs': '10', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [08/04/2021 08:44:40 WARNING 140208290785088] Loggers have already been setup.
# Process 1 is a worker.
# [08/04/2021 08:44:40 INFO 140208290785088] Using default worker.
# [08/04/2021 08:44:40 INFO 140208290785088] Checkpoint loading and saving are disabled.
# [2021-08-04 08:44:40.965] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-08-04 08:44:40.981] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1, "num_bytes": 4800}
# [08/04/2021 08:44:40 INFO 140208290785088] Create Store: local
# [2021-08-04 08:44:41.090] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 107, "num_examples": 11, "num_bytes": 50640}
# [08/04/2021 08:44:41 INFO 140208290785088] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f8468a34590>
# [08/04/2021 08:44:41 INFO 140208290785088] Scaling model computed with parameters:
#  {'stdev_label':
# [0.37173638]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [14.070388]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [0.09529999]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [70.381004]
# <NDArray 1 @cpu(0)>}
# [08/04/2021 08:44:41 INFO 140208290785088] nvidia-smi: took 0.031 seconds to run.
# [08/04/2021 08:44:41 INFO 140208290785088] nvidia-smi identified 0 GPUs.
# [08/04/2021 08:44:41 INFO 140208290785088] Number of GPUs being used: 0
# #metrics {"StartTime": 1628066681.2014658, "EndTime": 1628066681.2015028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1155.0, "count": 1, "min": 1155, "max": 1155}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-08-04 08:44:41.459] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 257, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1628066681.4590862, "EndTime": 1628066681.4591794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3284412708282471, "count": 1, "min": 0.3284412708282471, "max": 0.3284412708282471}}}
#
# #metrics {"StartTime": 1628066681.4592788, "EndTime": 1628066681.4592965, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33000543117523196, "count": 1, "min": 0.33000543117523196, "max": 0.33000543117523196}}}
#
# #metrics {"StartTime": 1628066681.4593468, "EndTime": 1628066681.459359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3279818181991577, "count": 1, "min": 0.3279818181991577, "max": 0.3279818181991577}}}
#
# #metrics {"StartTime": 1628066681.4594014, "EndTime": 1628066681.459413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3297176961898804, "count": 1, "min": 0.3297176961898804, "max": 0.3297176961898804}}}
#
# #metrics {"StartTime": 1628066681.459455, "EndTime": 1628066681.4594662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6131799964904785, "count": 1, "min": 0.6131799964904785, "max": 0.6131799964904785}}}
#
# #metrics {"StartTime": 1628066681.459515, "EndTime": 1628066681.4595275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5993497886657715, "count": 1, "min": 0.5993497886657715, "max": 0.5993497886657715}}}
#
# #metrics {"StartTime": 1628066681.459572, "EndTime": 1628066681.4595835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5915402145385742, "count": 1, "min": 0.5915402145385742, "max": 0.5915402145385742}}}
#
# #metrics {"StartTime": 1628066681.4596243, "EndTime": 1628066681.4596353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5906034259796142, "count": 1, "min": 0.5906034259796142, "max": 0.5906034259796142}}}
#
# #metrics {"StartTime": 1628066681.4596834, "EndTime": 1628066681.4596956, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3380057668685913, "count": 1, "min": 0.3380057668685913, "max": 0.3380057668685913}}}
#
# #metrics {"StartTime": 1628066681.4597435, "EndTime": 1628066681.4597554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3333428792953491, "count": 1, "min": 0.3333428792953491, "max": 0.3333428792953491}}}
#
# #metrics {"StartTime": 1628066681.4598029, "EndTime": 1628066681.4598145, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3313058567047119, "count": 1, "min": 0.3313058567047119, "max": 0.3313058567047119}}}
#
# #metrics {"StartTime": 1628066681.459859, "EndTime": 1628066681.45987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3324251089096069, "count": 1, "min": 0.3324251089096069, "max": 0.3324251089096069}}}
#
# #metrics {"StartTime": 1628066681.4599102, "EndTime": 1628066681.4599214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5994715633392333, "count": 1, "min": 0.5994715633392333, "max": 0.5994715633392333}}}
#
# #metrics {"StartTime": 1628066681.4599617, "EndTime": 1628066681.4599724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5847260608673096, "count": 1, "min": 0.5847260608673096, "max": 0.5847260608673096}}}
#
# #metrics {"StartTime": 1628066681.4600434, "EndTime": 1628066681.460057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5992612056732177, "count": 1, "min": 0.5992612056732177, "max": 0.5992612056732177}}}
#
# #metrics {"StartTime": 1628066681.4601016, "EndTime": 1628066681.4601135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5865831546783448, "count": 1, "min": 0.5865831546783448, "max": 0.5865831546783448}}}
#
# #metrics {"StartTime": 1628066681.4601536, "EndTime": 1628066681.460165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3298333988189697, "count": 1, "min": 0.3298333988189697, "max": 0.3298333988189697}}}
#
# #metrics {"StartTime": 1628066681.4602048, "EndTime": 1628066681.460216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3286715450286865, "count": 1, "min": 0.3286715450286865, "max": 0.3286715450286865}}}
#
# #metrics {"StartTime": 1628066681.4602559, "EndTime": 1628066681.4602673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33342279815673825, "count": 1, "min": 0.33342279815673825, "max": 0.33342279815673825}}}
#
# #metrics {"StartTime": 1628066681.4603076, "EndTime": 1628066681.460319, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33333204746246337, "count": 1, "min": 0.33333204746246337, "max": 0.33333204746246337}}}
#
# #metrics {"StartTime": 1628066681.4603589, "EndTime": 1628066681.4603698, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6403813247680664, "count": 1, "min": 0.6403813247680664, "max": 0.6403813247680664}}}
#
# #metrics {"StartTime": 1628066681.4604096, "EndTime": 1628066681.4604208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6445994949340821, "count": 1, "min": 0.6445994949340821, "max": 0.6445994949340821}}}
#
# #metrics {"StartTime": 1628066681.4604602, "EndTime": 1628066681.4604714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6184063663482666, "count": 1, "min": 0.6184063663482666, "max": 0.6184063663482666}}}
#
# #metrics {"StartTime": 1628066681.460511, "EndTime": 1628066681.4605222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6487670097351074, "count": 1, "min": 0.6487670097351074, "max": 0.6487670097351074}}}
#
# #metrics {"StartTime": 1628066681.4605615, "EndTime": 1628066681.4605725, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33471605777740476, "count": 1, "min": 0.33471605777740476, "max": 0.33471605777740476}}}
#
# #metrics {"StartTime": 1628066681.460612, "EndTime": 1628066681.460623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3311461763381958, "count": 1, "min": 0.3311461763381958, "max": 0.3311461763381958}}}
#
# #metrics {"StartTime": 1628066681.4606624, "EndTime": 1628066681.460673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33171886730194095, "count": 1, "min": 0.33171886730194095, "max": 0.33171886730194095}}}
#
# #metrics {"StartTime": 1628066681.4607224, "EndTime": 1628066681.4607375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33293819141387937, "count": 1, "min": 0.33293819141387937, "max": 0.33293819141387937}}}
#
# #metrics {"StartTime": 1628066681.4607935, "EndTime": 1628066681.4608107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6503389015197754, "count": 1, "min": 0.6503389015197754, "max": 0.6503389015197754}}}
#
# #metrics {"StartTime": 1628066681.4608617, "EndTime": 1628066681.4608774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6503626708984375, "count": 1, "min": 0.6503626708984375, "max": 0.6503626708984375}}}
#
# #metrics {"StartTime": 1628066681.4609315, "EndTime": 1628066681.4609485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6495811614990235, "count": 1, "min": 0.6495811614990235, "max": 0.6495811614990235}}}
#
# #metrics {"StartTime": 1628066681.4610088, "EndTime": 1628066681.4610255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6558773994445801, "count": 1, "min": 0.6558773994445801, "max": 0.6558773994445801}}}
#
# [08/04/2021 08:44:41 INFO 140208290785088] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.3284412708282471
# [08/04/2021 08:44:41 INFO 140208290785088] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.3279818181991577
# [08/04/2021 08:44:41 INFO 140208290785088] Epoch 0: Loss improved. Updating best model
# [08/04/2021 08:44:41 INFO 140208290785088] Saving model for epoch: 0
# [08/04/2021 08:44:41 INFO 140208290785088] Saved checkpoint to "/tmp/tmpuigk7k95/mx-mod-0000.params"
# [08/04/2021 08:44:41 INFO 140208290785088] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1628066681.2017844, "EndTime": 1628066681.4745638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2210.0, "count": 1, "min": 2210, "max": 2210}, "Total Batches Seen": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [08/04/2021 08:44:41 INFO 140208290785088] #throughput_metric: host=algo-1, train throughput=3865.38028870302 records/second
# [2021-08-04 08:44:41.706] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 231, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1628066681.7070215, "EndTime": 1628066681.7071013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2793946027755737, "count": 1, "min": 0.2793946027755737, "max": 0.2793946027755737}}}
#
# #metrics {"StartTime": 1628066681.7071824, "EndTime": 1628066681.7072012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27812488651275635, "count": 1, "min": 0.27812488651275635, "max": 0.27812488651275635}}}
#
# #metrics {"StartTime": 1628066681.7072542, "EndTime": 1628066681.7072713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27809330463409426, "count": 1, "min": 0.27809330463409426, "max": 0.27809330463409426}}}
#
# #metrics {"StartTime": 1628066681.707328, "EndTime": 1628066681.7073412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.309684962272644, "count": 1, "min": 0.309684962272644, "max": 0.309684962272644}}}
#
# #metrics {"StartTime": 1628066681.9713247, "EndTime": 1628066681.9713352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3517937278747559, "count": 1, "min": 0.3517937278747559, "max": 0.3517937278747559}}}
#
# #metrics {"StartTime": 1628066681.971374, "EndTime": 1628066681.9713848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.43407984161376956, "count": 1, "min": 0.43407984161376956, "max": 0.43407984161376956}}}
#
# #metrics {"StartTime": 1628066681.971424, "EndTime": 1628066681.9714346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2682839136123657, "count": 1, "min": 0.2682839136123657, "max": 0.2682839136123657}}}
#
# #metrics {"StartTime": 1628066681.9714732, "EndTime": 1628066681.971484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2674135856628418, "count": 1, "min": 0.2674135856628418, "max": 0.2674135856628418}}}
#
# #metrics {"StartTime": 1628066681.9715226, "EndTime": 1628066681.9715335, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2768888463973999, "count": 1, "min": 0.2768888463973999, "max": 0.2768888463973999}}}
#
# #metrics {"StartTime": 1628066681.9715722, "EndTime": 1628066681.971583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26907053565979006, "count": 1, "min": 0.26907053565979006, "max": 0.26907053565979006}}}
#
# #metrics {"StartTime": 1628066681.9716258, "EndTime": 1628066681.9716368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33167061424255373, "count": 1, "min": 0.33167061424255373, "max": 0.33167061424255373}}}
#
# #metrics {"StartTime": 1628066681.9716766, "EndTime": 1628066681.9716873, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33065947914123534, "count": 1, "min": 0.33065947914123534, "max": 0.33065947914123534}}}
#
# #metrics {"StartTime": 1628066681.9717283, "EndTime": 1628066681.9717379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3642907152175903, "count": 1, "min": 0.3642907152175903, "max": 0.3642907152175903}}}
#
# #metrics {"StartTime": 1628066681.9717653, "EndTime": 1628066681.971773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.37076904582977294, "count": 1, "min": 0.37076904582977294, "max": 0.37076904582977294}}}
#
# [08/04/2021 08:44:41 INFO 140208290785088] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.267076452255249
# [08/04/2021 08:44:41 INFO 140208290785088] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.2644825134277344
# [08/04/2021 08:44:41 INFO 140208290785088] Epoch 2: Loss improved. Updating best model
# [08/04/2021 08:44:41 INFO 140208290785088] Saving model for epoch: 2
# [08/04/2021 08:44:41 INFO 140208290785088] Saved checkpoint to "/tmp/tmpkd7ja14q/mx-mod-0000.params"
# [08/04/2021 08:44:41 INFO 140208290785088] #progress_metric: host=algo-1, completed 30.0 % of epochs
# #metrics {"StartTime": 1628066681.7206466, "EndTime": 1628066681.9856832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4320.0, "count": 1, "min": 4320, "max": 4320}, "Total Batches Seen": {"sum": 45.0, "count": 1, "min": 45, "max": 45}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [08/04/2021 08:44:41 INFO 140208290785088] #throughput_metric: host=algo-1, train throughput=3978.4423893361336 records/second
# [2021-08-04 08:44:42.330] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 343, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1628066682.3301735, "EndTime": 1628066682.3303015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.263014651298523, "count": 1, "min": 0.263014651298523, "max": 0.263014651298523}}}
#
# #metrics {"StartTime": 1628066682.3304334, "EndTime": 1628066682.330461, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2623221960067749, "count": 1, "min": 0.2623221960067749, "max": 0.2623221960067749}}}
#
# #metrics {"StartTime": 1628066682.3305569, "EndTime": 1628066682.3305779, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2618139877319336, "count": 1, "min": 0.2618139877319336, "max": 0.2618139877319336}}}
#
# #metrics {"StartTime": 1628066682.330637, "EndTime": 1628066682.3306544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26291169357299804, "count": 1, "min": 0.26291169357299804, "max": 0.26291169357299804}}}
#
# #metrics {"StartTime": 1628066682.3307633, "EndTime": 1628066682.330781, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.42989494705200193, "count": 1, "min": 0.42989494705200193, "max": 0.42989494705200193}}}
#
# #metrics {"StartTime": 1628066682.330836, "EndTime": 1628066682.330875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.35328960037231444, "count": 1, "min": 0.35328960037231444, "max": 0.35328960037231444}}}
#
# #metrics {"StartTime": 1628066682.3309581, "EndTime": 1628066682.3309772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3344859485626221, "count": 1, "min": 0.3344859485626221, "max": 0.3344859485626221}}}
#
# #metrics {"StartTime": 1628066682.3310318, "EndTime": 1628066682.3310468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3255274181365967, "count": 1, "min": 0.3255274181365967, "max": 0.3255274181365967}}}
#
# #metrics {"StartTime": 1628066682.3311253, "EndTime": 1628066682.3311431, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26593627643585205, "count": 1, "min": 0.26593627643585205, "max": 0.26593627643585205}}}
#
# #metrics {"StartTime": 1628066682.3312256, "EndTime": 1628066682.3312435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2688338861465454, "count": 1, "min": 0.2688338861465454, "max": 0.2688338861465454}}}
#
# #metrics {"StartTime": 1628066682.331295, "EndTime": 1628066682.3313098, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2647345485687256, "count": 1, "min": 0.2647345485687256, "max": 0.2647345485687256}}}
#
# #metrics {"StartTime": 1628066682.3313942, "EndTime": 1628066682.331413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2636748828887939, "count": 1, "min": 0.2636748828887939, "max": 0.2636748828887939}}}
#
# #metrics {"StartTime": 1628066682.3314977, "EndTime": 1628066682.3315177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.34206385135650635, "count": 1, "min": 0.34206385135650635, "max": 0.34206385135650635}}}
#
# #metrics {"StartTime": 1628066682.3315747, "EndTime": 1628066682.331591, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28138245487213137, "count": 1, "min": 0.28138245487213137, "max": 0.28138245487213137}}}
#
# #metrics {"StartTime": 1628066682.33168, "EndTime": 1628066682.3316987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.35676657581329346, "count": 1, "min": 0.35676657581329346, "max": 0.35676657581329346}}}
#
# ...
#
# #metrics {"StartTime": 1628066684.1989667, "EndTime": 1628066684.1989865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.258961895942688, "count": 1, "min": 0.258961895942688, "max": 0.258961895942688}}}
#
# #metrics {"StartTime": 1628066684.1990492, "EndTime": 1628066684.1990662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.25788556480407715, "count": 1, "min": 0.25788556480407715, "max": 0.25788556480407715}}}
#
# #metrics {"StartTime": 1628066684.1991239, "EndTime": 1628066684.1991413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3959256381988525, "count": 1, "min": 0.3959256381988525, "max": 0.3959256381988525}}}
#
# #metrics {"StartTime": 1628066684.1991975, "EndTime": 1628066684.1992157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3098989734649658, "count": 1, "min": 0.3098989734649658, "max": 0.3098989734649658}}}
#
# #metrics {"StartTime": 1628066684.1992724, "EndTime": 1628066684.199289, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3180269136428833, "count": 1, "min": 0.3180269136428833, "max": 0.3180269136428833}}}
#
# #metrics {"StartTime": 1628066684.199345, "EndTime": 1628066684.1993628, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2964780788421631, "count": 1, "min": 0.2964780788421631, "max": 0.2964780788421631}}}
#
# #metrics {"StartTime": 1628066684.199407, "EndTime": 1628066684.199423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2593760356903076, "count": 1, "min": 0.2593760356903076, "max": 0.2593760356903076}}}
#
# #metrics {"StartTime": 1628066684.1994662, "EndTime": 1628066684.1994822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2588031740188599, "count": 1, "min": 0.2588031740188599, "max": 0.2588031740188599}}}
#
# #metrics {"StartTime": 1628066684.1995363, "EndTime": 1628066684.199553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.25758341693878173, "count": 1, "min": 0.25758341693878173, "max": 0.25758341693878173}}}
#
# #metrics {"StartTime": 1628066684.199608, "EndTime": 1628066684.1996255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2589294195175171, "count": 1, "min": 0.2589294195175171, "max": 0.2589294195175171}}}
#
# #metrics {"StartTime": 1628066684.199682, "EndTime": 1628066684.1996984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3648002452850342, "count": 1, "min": 0.3648002452850342, "max": 0.3648002452850342}}}
#
# #metrics {"StartTime": 1628066684.1997669, "EndTime": 1628066684.1997845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31358861160278323, "count": 1, "min": 0.31358861160278323, "max": 0.31358861160278323}}}
#
# #metrics {"StartTime": 1628066684.1998522, "EndTime": 1628066684.1998696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.38176515579223635, "count": 1, "min": 0.38176515579223635, "max": 0.38176515579223635}}}
#
# #metrics {"StartTime": 1628066684.199938, "EndTime": 1628066684.1999557, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28712178707122804, "count": 1, "min": 0.28712178707122804, "max": 0.28712178707122804}}}
#
# #metrics {"StartTime": 1628066684.2000356, "EndTime": 1628066684.2000537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2600080966949463, "count": 1, "min": 0.2600080966949463, "max": 0.2600080966949463}}}
#
# #metrics {"StartTime": 1628066684.200093, "EndTime": 1628066684.2001073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26120479488372805, "count": 1, "min": 0.26120479488372805, "max": 0.26120479488372805}}}
#
# #metrics {"StartTime": 1628066684.2001433, "EndTime": 1628066684.200153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2592298927307129, "count": 1, "min": 0.2592298927307129, "max": 0.2592298927307129}}}
#
# #metrics {"StartTime": 1628066684.2001808, "EndTime": 1628066684.20019, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.25798305797576904, "count": 1, "min": 0.25798305797576904, "max": 0.25798305797576904}}}
#
# #metrics {"StartTime": 1628066684.2002485, "EndTime": 1628066684.2002656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27785352420806886, "count": 1, "min": 0.27785352420806886, "max": 0.27785352420806886}}}
#
# #metrics {"StartTime": 1628066684.2003295, "EndTime": 1628066684.2003477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2980986614227295, "count": 1, "min": 0.2980986614227295, "max": 0.2980986614227295}}}
#
# #metrics {"StartTime": 1628066684.200406, "EndTime": 1628066684.2004242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3075559091567993, "count": 1, "min": 0.3075559091567993, "max": 0.3075559091567993}}}
#
# #metrics {"StartTime": 1628066684.2004824, "EndTime": 1628066684.2005002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2888190851211548, "count": 1, "min": 0.2888190851211548, "max": 0.2888190851211548}}}
#
# #metrics {"StartTime": 1628066684.2005594, "EndTime": 1628066684.2005768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26261290645599367, "count": 1, "min": 0.26261290645599367, "max": 0.26261290645599367}}}
#
# #metrics {"StartTime": 1628066684.200633, "EndTime": 1628066684.200651, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2605472192764282, "count": 1, "min": 0.2605472192764282, "max": 0.2605472192764282}}}
#
# #metrics {"StartTime": 1628066684.2007163, "EndTime": 1628066684.2007346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.25786705017089845, "count": 1, "min": 0.25786705017089845, "max": 0.25786705017089845}}}
#
# #metrics {"StartTime": 1628066684.2007916, "EndTime": 1628066684.200809, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2593344497680664, "count": 1, "min": 0.2593344497680664, "max": 0.2593344497680664}}}
#
# #metrics {"StartTime": 1628066684.200878, "EndTime": 1628066684.2008944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.30422871112823485, "count": 1, "min": 0.30422871112823485, "max": 0.30422871112823485}}}
#
# #metrics {"StartTime": 1628066684.2009528, "EndTime": 1628066684.20097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.30749792671203613, "count": 1, "min": 0.30749792671203613, "max": 0.30749792671203613}}}
#
# #metrics {"StartTime": 1628066684.2010286, "EndTime": 1628066684.2010455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32059776496887205, "count": 1, "min": 0.32059776496887205, "max": 0.32059776496887205}}}
#
# #metrics {"StartTime": 1628066684.2011108, "EndTime": 1628066684.2011268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3095279741287231, "count": 1, "min": 0.3095279741287231, "max": 0.3095279741287231}}}
#
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, epoch=9, train absolute_loss_objective <loss>=0.2588847541809082
# [08/04/2021 08:44:44 INFO 140208290785088] #early_stopping_criteria_metric: host=algo-1, epoch=9, criteria=absolute_loss_objective, value=0.25758341693878173
# [08/04/2021 08:44:44 INFO 140208290785088] Saving model for epoch: 9
# [08/04/2021 08:44:44 INFO 140208290785088] Saved checkpoint to "/tmp/tmp_3y0xop6/mx-mod-0000.params"
# [08/04/2021 08:44:44 INFO 140208290785088] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1628066683.9466205, "EndTime": 1628066684.2106755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 11705.0, "count": 1, "min": 11705, "max": 11705}, "Total Batches Seen": {"sum": 122.0, "count": 1, "min": 122, "max": 122}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [08/04/2021 08:44:44 INFO 140208290785088] #throughput_metric: host=algo-1, train throughput=3993.1261415401495 records/second
# [08/04/2021 08:44:44 WARNING 140208290785088] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/04/2021 08:44:44 WARNING 140208290785088] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-08-04 08:44:44.211] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 0, "num_examples": 1, "num_bytes": 4800}
# [2021-08-04 08:44:44.227] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 12, "num_examples": 11, "num_bytes": 50640}
# [08/04/2021 08:44:44 INFO 140208290785088] #train_score (algo-1) : ('absolute_loss_objective', 0.10713686558872602)
# [08/04/2021 08:44:44 INFO 140208290785088] #train_score (algo-1) : ('mse', 0.1784727594863747)
# [08/04/2021 08:44:44 INFO 140208290785088] #train_score (algo-1) : ('absolute_loss', 0.10713686558872602)
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=0.10713686558872602
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, train mse <loss>=0.1784727594863747
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, train absolute_loss <loss>=0.10713686558872602
# [08/04/2021 08:44:44 INFO 140208290785088] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 100, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [08/04/2021 08:44:44 INFO 140208290785088] Saved checkpoint to "/tmp/tmptelg_5q3/mx-mod-0000.params"
# [2021-08-04 08:44:44.230] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 3265, "num_examples": 1, "num_bytes": 4800}
# [2021-08-04 08:44:44.235] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 4, "num_examples": 3, "num_bytes": 12672}
# #metrics {"StartTime": 1628066684.230834, "EndTime": 1628066684.236032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 264.0, "count": 1, "min": 264, "max": 264}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 264.0, "count": 1, "min": 264, "max": 264}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 264.0, "count": 1, "min": 264, "max": 264}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
#
# [08/04/2021 08:44:44 INFO 140208290785088] #test_score (algo-1) : ('absolute_loss_objective', 0.14737175450180517)
# [08/04/2021 08:44:44 INFO 140208290785088] #test_score (algo-1) : ('mse', 0.26619122606335266)
# [08/04/2021 08:44:44 INFO 140208290785088] #test_score (algo-1) : ('absolute_loss', 0.14737175450180517)
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, test absolute_loss_objective <loss>=0.14737175450180517
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, test mse <loss>=0.26619122606335266
# [08/04/2021 08:44:44 INFO 140208290785088] #quality_metric: host=algo-1, test absolute_loss <loss>=0.14737175450180517
# #metrics {"StartTime": 1628066680.9639156, "EndTime": 1628066684.2401438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 235.5937957763672, "count": 1, "min": 235.5937957763672, "max": 235.5937957763672}, "epochs": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "check_early_stopping.time": {"sum": 11.515378952026367, "count": 10, "min": 0.21886825561523438, "max": 1.8732547760009766}, "update.time": {"sum": 2966.602325439453, "count": 10, "min": 242.47360229492188, "max": 413.35296630859375}, "finalize.time": {"sum": 17.19832420349121, "count": 1, "min": 17.19832420349121, "max": 17.19832420349121}, "setuptime": {"sum": 24.183988571166992, "count": 1, "min": 24.183988571166992, "max": 24.183988571166992}, "totaltime": {"sum": 3493.9985275268555, "count": 1, "min": 3493.9985275268555, "max": 3493.9985275268555}}}
#
#
# 2021-08-04 08:44:59 Uploading - Uploading generated training model
# 2021-08-04 08:44:59 Completed - Training job completed
# Training seconds: 66
# Billable seconds: 66

# %% [markdown]
# ## Deploying the Model to Make Predictions

# %%
# An instance of the linear-learner predictor is created
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type="ml.t2.medium")
# Out:
# ---------------!

# %%
# Linear predictor configurations
linear_predictor.serializer =csv_serializer

linear_predictor.deserializer = json_deserializer

# %%
# Making some predictions using the test data.
result = linear_predictor.predict(X_test)

y_predictions = np.array([r["score"] for r in result["predictions"]])

y_predictions[:5]
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# array([0.00213632, 0.00128301, 0.00213632, 0.00099857, 0.00206521])

# %% [markdown]
# ## Model Evaluation

# %%
# Plotting predicted Vs. actual values
plt.plot(np.array(y_test), label="actual")
plt.plot(y_predictions, label="predict")
plt.legend()
plt.show()

# %%
# Calculating the RMSE and R2 scores
rmse = np.sqrt(mean_squared_error(y_test, y_predictions))

r2 = r2_score(y_test, y_predictions)

print(f"RMSE: {rmse}")
print()
print(f"R2 score: {r2}")
# Out:
# RMSE: 0.5159372475076323
#
# R2 score: -0.08629501776936332

# %% [markdown]
# ## Delete Amazon SageMaker end-point

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
