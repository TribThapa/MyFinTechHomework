# %%
import os
from web3 import Web3
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:8545"))

w3.eth.getBalance("0265741451c901d4cd9f7c9603e068d4d30868806e461e76721f08512fe5922ece")

private_key = os.getenv("cNib1MxnjWLT3YNFZH4HmJAWxGNLWqKiR3B3S69X5Q9RiCC7bdq6")

print(private_key)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\envs\ethereum\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~\anaconda3\envs\ethereum\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda3\envs\ethereum\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...
