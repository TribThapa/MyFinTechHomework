# %% [markdown]
# # Reading a CSV as a Pandas DataFrame

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas and pathlib
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
data = Path(r'C:\Users\TribThapa\Desktop\Thapa\ResearchFellow\Courses\FinTech_Bootcamp_MonashUni2021\monu-mel-virt-fin-pt-05-2021-u-c\Activities\Week 4\2\01-csv-01\Resources\people.csv')

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame

# %%
# Use the file path to read the CSV into a DataFrame
data_df = pd.read_csv(data)

# %% [markdown]
# ### 4. Display a Few Rows of the DataFrame

# %%
# Use the `head` function to display a few rows of the top of the DataFrame
data_df.head(10)
# Out:
#      id  first_name    last_name                            email  gender  \
# 0   1.0     Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1   2.0     Huntley        Rupke              hrupke1@reuters.com    Male
# 2   3.0      Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3   4.0      Cullie          NaN               cputten3@nymag.com    Male
# 4   5.0       Ariel    Strangman       astrangman4@bravesites.com  Female
# 5   6.0     Antonio    Snozzwell            asnozzwell5@mysql.com    Male
# 6   7.0       Darya     Neathway            dneathway6@seesaa.net  Female
# 7   8.0     Helaina       Duding               hduding7@topsy.com  Female
# 8   9.0  Gerhardine   Franzolini             gfranzolini8@msn.com  Female
# 9  10.0       Charo        Traut               ctraut9@oracle.com  Female
#
#                                             uni_grad  \
# 0                                  Aurora University
# 1                      Osaka University of Economics
# 2                                  Ludong University
# 3  Université des Sciences et de la Technologie d...
# 4                             Boise State University
# 5                                 Babcock University
# 6                                     Molloy College
# 7                                St. Paul University
# 8                  Fundação Educacional de Ituverava
# 9                                 Cornell University
#
#                   job_title    Income
# 0        Nurse Practicioner   58135.0
# 1           Project Manager   96053.0
# 2        Environmental Tech   59196.0
# 3           Legal Assistant   88493.0
# 4           Project Manager   89073.0
# 5          Technical Writer  119916.0
# 6    Administrative Officer   77705.0
# 7           Staff Scientist   57166.0
# 8  Environmental Specialist   73051.0
# 9            Programmer III   90631.0

# %% [markdown]
# ### 5. Generate Summary Statistics on the DataFrame

# %%
# Use the `include` parameter set to 'all' to include all columns (and datatypes)
data_df.describe(include='all')
# Out:
#                  id first_name  last_name                 email gender  \
# count    996.000000        993        990                   992    998
# unique          NaN        914        974                   991      2
# top             NaN     Israel  Yurchenko  ayang@codedrills.com   Male
# freq            NaN          3          2                     2    508
# mean     500.213855        NaN        NaN                   NaN    NaN
# std      289.172174        NaN        NaN                   NaN    NaN
# min        1.000000        NaN        NaN                   NaN    NaN
# 25%      249.750000        NaN        NaN                   NaN    NaN
# 50%      500.000000        NaN        NaN                   NaN    NaN
# 75%      750.250000        NaN        NaN                   NaN    NaN
# max     1000.000000        NaN        NaN                   NaN    NaN
#
#                                                  uni_grad  \
# count                                                 991
# unique                                                939
# top     Université des Sciences et de la Technologie d...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                     job_title         Income
# count                     998     998.000000
# unique                    183            NaN
# top     Chief Design Engineer            NaN
# freq                       16            NaN
# mean                      NaN   84691.693387
# std                       NaN   20185.664319
# min                       NaN   50013.000000
# 25%                       NaN   67353.000000
# 50%                       NaN   84296.000000
# 75%                       NaN  102374.750000
# max                       NaN  119987.000000

# %%
data_df.count()
# Out:
# id            996
# first_name    993
# last_name     990
# email         992
# gender        998
# uni_grad      991
# job_title     998
# Income        998
# dtype: int64

# %%
data_df.max()
# Out:
# id          1000.0
# Income    119987.0
# dtype: float64

# %%
data_df.std()
# Out:
# id          289.172174
# Income    20185.664319
# dtype: float64
