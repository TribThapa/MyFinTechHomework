# %%
import pandas as pd
from pathlib import Path

# %%
data = Path(r'C:\Users\TribThapa\Desktop\Thapa\ResearchFellow\Courses\FinTech_Bootcamp_MonashUni2021\monu-mel-virt-fin-pt-05-2021-u-c\Activities\Week 3\2\07-Stu_Indexing\Resources\loans.csv')

data_df = pd.read_csv(data)
data_df.head(10)
# Out:
# C:\Users\TribThapa\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (11,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
# 5      30000        30000          30000.0  60 months    0.1894       777.23
# 6      23000        23000          23000.0  60 months    0.2089       620.81
# 7      32075        32075          32075.0  60 months    0.1180       710.26
# ...

# %%
data_df.describe(include='all')
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv       term  \
# count   128412.000000  128412.000000    128412.000000     128412
# unique            NaN            NaN              NaN          2
# top               NaN            NaN              NaN  36 months
# freq              NaN            NaN              NaN      88179
# mean     15971.321021   15971.321021     15968.498166        NaN
# std      10150.384233   10150.384233     10152.168970        NaN
# min       1000.000000    1000.000000       725.000000        NaN
# 25%       8000.000000    8000.000000      8000.000000        NaN
# 50%      14000.000000   14000.000000     14000.000000        NaN
# 75%      21600.000000   21600.000000     21600.000000        NaN
# max      40000.000000   40000.000000     40000.000000        NaN
#
#              int_rate    installment   grade sub_grade emp_title emp_length  \
# count   128412.000000  128412.000000  128412    128412    107465     116708
# ...

# %%
ColNames = ['loan_amnt', 'term', 'int_rate', 'emp_title', 'annual_inc', 'purpose']

filtered_df = data_df.loc[:, ColNames]

filtered_df.count()
# Out:
# loan_amnt     128412
# term          128412
# int_rate      128412
# emp_title     107465
# annual_inc    128412
# purpose       128412
# dtype: int64

# %%
filtered_df = filtered_df.loc[filtered_df['term'] == '36 months']

filtered_df.count()
# Out:
# loan_amnt     88179
# term          88179
# int_rate      88179
# emp_title     72510
# annual_inc    88179
# purpose       88179
# dtype: int64

# %%
filtered_df['emp_title'].sample(10)
# Out:
# 4598                                   Salesman
# 30614     Assistant Vice President, Philanthropy
# 97673                               Loan Officer
# 121167                                       NaN
# 77242                       Accounts coordinator
# 47320                           Registered nurse
# 8785                                         NaN
# 128261                                       NaN
# 43376                                        NaN
# 43998                            Project Manager
# Name: emp_title, dtype: object

# %%
filtered_df['emp_title'].isnull().replace('NaN', 'Unknown')
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 128407    False
# 128408    False
# 128409    False
# 128410     True
# 128411    False
# Name: emp_title, Length: 88179, dtype: bool

# %%
filtered_df['is_Null'] = filtered_df['emp_title'].isnull()

filtered_df
# Out:
#         loan_amnt       term  int_rate             emp_title annual_inc  \
# 0           10000  36 months    0.1033                   NaN     280000
# 1            4000  36 months    0.2340              Security      90000
# 2            5000  36 months    0.1797        Administrative      59280
# 3            9600  36 months    0.1298                   NaN      35704
# 4            2500  36 months    0.1356                  Chef      55000
# ...           ...        ...       ...                   ...        ...
# 128407      23000  36 months    0.1502        Tax Consultant    75000.0
# 128408      10000  36 months    0.1502        security guard    38000.0
# 128409       5000  36 months    0.1356          Payoff Clerk    35360.0
# 128410      10000  36 months    0.1106                   NaN    44400.0
# 128411      10000  36 months    0.1691  Key Accounts Manager    80000.0
#
#                    purpose  is_Null
# 0       debt_consolidation     True
# ...

# %%
filtered_df.loc[filtered_df.is_Null == True, 'emp_title'] = "Unknown"

filtered_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title annual_inc  \
# 0      10000  36 months    0.1033         Unknown     280000
# 1       4000  36 months    0.2340        Security      90000
# 2       5000  36 months    0.1797  Administrative      59280
# 3       9600  36 months    0.1298         Unknown      35704
# 4       2500  36 months    0.1356            Chef      55000
#
#               purpose  is_Null
# 0  debt_consolidation     True
# 1  debt_consolidation    False
# 2  debt_consolidation    False
# 3    home_improvement     True
# 4  debt_consolidation    False
