# %%
cheer = ["Python", "FinTech", "Money"]
print(cheer)
print(len(cheer))
print(range(len(cheer)))
# Out:
# ['Python', 'FinTech', 'Money']
# 3
# range(0, 3)

# %%
# Below strings can be used to add fun
cheer_symbol = "*\O/*"
cheer_symbol_2 = "ヘ( ^o^)ノ＼(^_^ )"

# %%
#loop through string

for i in range(len(cheer)):
    print(i)
    for x in cheer[i]:
        print(x)
        print("Give me a " + x + "!")
        print(x + "!")
    print("What does that spell?")
    print(cheer[i] + " WooHoo! Go " + cheer[i] + "!")
    print(cheer_symbol * 3)
    print(cheer_symbol_2)
    print()
# Out:
# 0
# P
# Give me a P!
# P!
# y
# Give me a y!
# y!
# t
# Give me a t!
# t!
# h
# Give me a h!
# h!
# o
# Give me a o!
# o!
# n
# Give me a n!
# n!
# What does that spell?
# Python WooHoo! Go Python!
# *\O/**\O/**\O/*
# ヘ( ^o^)ノ＼(^_^ )
#
# 1
# F
# Give me a F!
# F!
# i
# Give me a i!
# i!
# n
# Give me a n!
# n!
# T
# Give me a T!
# T!
# e
# Give me a e!
# e!
# c
# Give me a c!
# c!
# h
# Give me a h!
# h!
# What does that spell?
# FinTech WooHoo! Go FinTech!
# *\O/**\O/**\O/*
# ヘ( ^o^)ノ＼(^_^ )
#
# 2
# M
# Give me a M!
# M!
# o
# Give me a o!
# o!
# n
# Give me a n!
# n!
# e
# Give me a e!
# e!
# y
# Give me a y!
# y!
# What does that spell?
# Money WooHoo! Go Money!
# *\O/**\O/**\O/*
# ヘ( ^o^)ノ＼(^_^ )

# %%
# Create a list of Pokemon
print("Creating a list of Pokemon...")

pokemon = ["Pikachu", "Charizard", "bulbasaur", "Gyarados", "Dragonite", "Onyx"]
print(pokemon)
print()

#Print element at index 2
print("Printing the thrid Pokemon...")
print(pokemon[2])
print()

#Print elements from index 2 to 5
print("Printing 3rd Pokemon to 5th Pokemon")
print(pokemon[3:])
print()

#Print elements from beginning of list to index 3
print("Printing every Pokemon up to first 3")
print(pokemon[:3])
print()

#Print every other element
print("Printing every other element")
print(pokemon[:: 2])
print()

#Print the last element of the list
print("Printing the last Pokemon on the list....")
print(pokemon[-1])
print()

#Find the index of the particular element name
print("Determining the order of Pokemon 'Gyarados'....")
print(pokemon)
print(pokemon.index("Gyarados"))
print()

#Change a specified element within the list at a given index
print("Changing Pokemon name 'Pikachu' to 'Raichu'....")
pokemon[0] = "Raichu"
print(pokemon)
print()

#Add an element to the end of the list
print("Adding a new Pokemon to the end of the list...")
pokemon.append("Magikarp")
print(pokemon)
print()

#Remove an element from the list based on the given element name
print("Removing 'Magikarp'...")
pokemon.remove("Magikarp")
print(pokemon)
print()

#Remove an elemnt from the list based upon a certain index
print("Removing 'Bulbasaur' based off of its index")
bulbasaur_index = pokemon.index('bulbasaur')
print(bulbasaur_index)
pokemon.pop(bulbasaur_index)
print(pokemon)
print()

#Calculate the number of elements within the list
print("Calculating the number of Pokemon...")
print(len(pokemon))
print()
# Out:
# Creating a list of Pokemon...
# ['Pikachu', 'Charizard', 'bulbasaur', 'Gyarados', 'Dragonite', 'Onyx']
#
# Printing the thrid Pokemon...
# bulbasaur
#
# Printing 3rd Pokemon to 5th Pokemon
# ['Gyarados', 'Dragonite', 'Onyx']
#
# Printing every Pokemon up to first 3
# ['Pikachu', 'Charizard', 'bulbasaur']
#
# Printing every other element
# ['Pikachu', 'bulbasaur', 'Dragonite']
#
# Printing the last Pokemon on the list....
# Onyx
#
# Determining the order of Pokemon 'Gyarados'....
# ['Pikachu', 'Charizard', 'bulbasaur', 'Gyarados', 'Dragonite', 'Onyx']
# 3
#
# Changing Pokemon name 'Pikachu' to 'Raichu'....
# ['Raichu', 'Charizard', 'bulbasaur', 'Gyarados', 'Dragonite', 'Onyx']
#
# Adding a new Pokemon to the end of the list...
# ['Raichu', 'Charizard', 'bulbasaur', 'Gyarados', 'Dragonite', 'Onyx', 'Magikarp']
#
# Removing 'Magikarp'...
# ['Raichu', 'Charizard', 'bulbasaur', 'Gyarados', 'Dragonite', 'Onyx']
#
# Removing 'Bulbasaur' based off of its index
# 2
# ['Raichu', 'Charizard', 'Gyarados', 'Dragonite', 'Onyx']
#
# Calculating the number of Pokemon...
# 5

# %%
# Out:
# Printing the thrid Pokemon...
# bulbasaur
